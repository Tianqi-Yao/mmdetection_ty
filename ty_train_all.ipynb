# %%
# !python tools/train.py configs/a_swd/rtmdet-ins_m_8xb32-300e_coco.py
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 02/20 02:31:46 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 104918269
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /home/tianqi/miniconda3/envs/mmcv
#     NVCC: Cuda compilation tools, release 12.4, V12.4.131
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.11.0
#     MMEngine: 0.10.6
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 104918269
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/20 02:31:47 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# base_lr = 0.004
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0002,
#         priority=49,
#         type='EMAHook',
#         update_buffers=True),
#     dict(
#         switch_epoch=280,
#         switch_pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 poly2mask=False,
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.1,
#                     2.0,
#                 ),
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 allow_negative_crop=True,
#                 crop_size=(
#                     640,
#                     640,
#                 ),
#                 recompute_bbox=True,
#                 type='RandomCrop'),
#             dict(min_gt_bbox_wh=(
#                 1,
#                 1,
#             ), type='FilterAnnotations'),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 pad_val=dict(img=(
#                     114,
#                     114,
#                     114,
#                 )),
#                 size=(
#                     640,
#                     640,
#                 ),
#                 type='Pad'),
#             dict(type='PackDetInputs'),
#         ],
#         type='PipelineSwitchHook'),
# ]
# data_root = 'data/swd/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, show=False, type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_scales = [
#     (
#         640,
#         640,
#     ),
#     (
#         320,
#         320,
#     ),
#     (
#         960,
#         960,
#     ),
# ]
# interval = 10
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmdetection/v3.0/rtmdet/rtmdet-ins_m_8xb32-300e_coco/rtmdet-ins_m_8xb32-300e_coco_20221123_001039-6eba602e.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 300
# metainfo = dict(
#     classes=('swd', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         arch='P5',
#         channel_attention=True,
#         deepen_factor=0.67,
#         expand_ratio=0.5,
#         norm_cfg=dict(type='SyncBN'),
#         type='CSPNeXt',
#         widen_factor=0.75),
#     bbox_head=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         anchor_generator=dict(
#             offset=0, strides=[
#                 8,
#                 16,
#                 32,
#             ], type='MlvlPointGenerator'),
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         feat_channels=192,
#         in_channels=192,
#         loss_bbox=dict(loss_weight=2.0, type='GIoULoss'),
#         loss_cls=dict(
#             beta=2.0,
#             loss_weight=1.0,
#             type='QualityFocalLoss',
#             use_sigmoid=True),
#         loss_mask=dict(
#             eps=5e-06, loss_weight=2.0, reduction='mean', type='DiceLoss'),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=1,
#         pred_kernel_size=1,
#         share_conv=True,
#         stacked_convs=2,
#         type='RTMDetInsSepBNHead'),
#     data_preprocessor=dict(
#         batch_augments=None,
#         bgr_to_rgb=False,
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             57.375,
#             57.12,
#             58.395,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='SiLU'),
#         expand_ratio=0.5,
#         in_channels=[
#             192,
#             384,
#             768,
#         ],
#         norm_cfg=dict(type='SyncBN'),
#         num_csp_blocks=2,
#         out_channels=192,
#         type='CSPNeXtPAFPN'),
#     test_cfg=dict(
#         mask_thr_binary=0.5,
#         max_per_img=100,
#         min_bbox_size=0,
#         nms=dict(iou_threshold=0.6, type='nms'),
#         nms_pre=1000,
#         score_thr=0.05),
#     train_cfg=dict(
#         allowed_border=-1,
#         assigner=dict(topk=13, type='DynamicSoftLabelAssigner'),
#         debug=False,
#         pos_weight=-1),
#     type='RTMDet')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, momentum=0.9, type='SGD', weight_decay=0.0001),
#     paramwise_cfg=dict(
#         bias_decay_mult=0, bypass_duplicate=True, norm_decay_mult=0),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=1e-05,
#         type='LinearLR'),
#     dict(
#         T_max=150,
#         begin=150,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=300,
#         eta_min=0.0002,
#         type='CosineAnnealingLR'),
# ]
# resume = False
# stage2_num_epochs = 20
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=5,
#     dataset=dict(
#         ann_file='test/test.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/swd/',
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 640,
#             ), type='Resize'),
#             dict(
#                 pad_val=dict(img=(
#                     114,
#                     114,
#                     114,
#                 )),
#                 size=(
#                     640,
#                     640,
#                 ),
#                 type='Pad'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=10,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/swd/test/test.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         640,
#         640,
#     ), type='Resize'),
#     dict(pad_val=dict(img=(
#         114,
#         114,
#         114,
#     )), size=(
#         640,
#         640,
#     ), type='Pad'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(
#     dynamic_intervals=[
#         (
#             280,
#             1,
#         ),
#     ],
#     max_epochs=100,
#     type='EpochBasedTrainLoop',
#     val_interval=5)
# train_dataloader = dict(
#     batch_sampler=None,
#     batch_size=4,
#     dataset=dict(
#         ann_file='train/train.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 poly2mask=False,
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True),
#             dict(img_scale=(
#                 640,
#                 640,
#             ), pad_val=114.0, type='CachedMosaic'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.1,
#                     2.0,
#                 ),
#                 scale=(
#                     1280,
#                     1280,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 allow_negative_crop=True,
#                 crop_size=(
#                     640,
#                     640,
#                 ),
#                 recompute_bbox=True,
#                 type='RandomCrop'),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 pad_val=dict(img=(
#                     114,
#                     114,
#                     114,
#                 )),
#                 size=(
#                     640,
#                     640,
#                 ),
#                 type='Pad'),
#             dict(
#                 img_scale=(
#                     640,
#                     640,
#                 ),
#                 max_cached_images=20,
#                 pad_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 ratio_range=(
#                     1.0,
#                     1.0,
#                 ),
#                 type='CachedMixUp'),
#             dict(min_gt_bbox_wh=(
#                 1,
#                 1,
#             ), type='FilterAnnotations'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=10,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         poly2mask=False,
#         type='LoadAnnotations',
#         with_bbox=True,
#         with_mask=True),
#     dict(img_scale=(
#         640,
#         640,
#     ), pad_val=114.0, type='CachedMosaic'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.1,
#             2.0,
#         ),
#         scale=(
#             1280,
#             1280,
#         ),
#         type='RandomResize'),
#     dict(
#         allow_negative_crop=True,
#         crop_size=(
#             640,
#             640,
#         ),
#         recompute_bbox=True,
#         type='RandomCrop'),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(pad_val=dict(img=(
#         114,
#         114,
#         114,
#     )), size=(
#         640,
#         640,
#     ), type='Pad'),
#     dict(
#         img_scale=(
#             640,
#             640,
#         ),
#         max_cached_images=20,
#         pad_val=(
#             114,
#             114,
#             114,
#         ),
#         ratio_range=(
#             1.0,
#             1.0,
#         ),
#         type='CachedMixUp'),
#     dict(min_gt_bbox_wh=(
#         1,
#         1,
#     ), type='FilterAnnotations'),
#     dict(type='PackDetInputs'),
# ]
# train_pipeline_stage2 = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         poly2mask=False,
#         type='LoadAnnotations',
#         with_bbox=True,
#         with_mask=True),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.1,
#             2.0,
#         ),
#         scale=(
#             640,
#             640,
#         ),
#         type='RandomResize'),
#     dict(
#         allow_negative_crop=True,
#         crop_size=(
#             640,
#             640,
#         ),
#         recompute_bbox=True,
#         type='RandomCrop'),
#     dict(min_gt_bbox_wh=(
#         1,
#         1,
#     ), type='FilterAnnotations'),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(pad_val=dict(img=(
#         114,
#         114,
#         114,
#     )), size=(
#         640,
#         640,
#     ), type='Pad'),
#     dict(type='PackDetInputs'),
# ]
# tta_model = dict(
#     tta_cfg=dict(max_per_img=100, nms=dict(iou_threshold=0.6, type='nms')),
#     type='DetTTAModel')
# tta_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale=(
#                     640,
#                     640,
#                 ), type='Resize'),
#                 dict(keep_ratio=True, scale=(
#                     320,
#                     320,
#                 ), type='Resize'),
#                 dict(keep_ratio=True, scale=(
#                     960,
#                     960,
#                 ), type='Resize'),
#             ],
#             [
#                 dict(prob=1.0, type='RandomFlip'),
#                 dict(prob=0.0, type='RandomFlip'),
#             ],
#             [
#                 dict(
#                     pad_val=dict(img=(
#                         114,
#                         114,
#                         114,
#                     )),
#                     size=(
#                         960,
#                         960,
#                     ),
#                     type='Pad'),
#             ],
#             [
#                 dict(type='LoadAnnotations', with_bbox=True),
#             ],
#             [
#                 dict(
#                     meta_keys=(
#                         'img_id',
#                         'img_path',
#                         'ori_shape',
#                         'img_shape',
#                         'scale_factor',
#                         'flip',
#                         'flip_direction',
#                     ),
#                     type='PackDetInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=5,
#     dataset=dict(
#         ann_file='val/val.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='data/swd/',
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 640,
#                 640,
#             ), type='Resize'),
#             dict(
#                 pad_val=dict(img=(
#                     114,
#                     114,
#                     114,
#                 )),
#                 size=(
#                     640,
#                     640,
#                 ),
#                 type='Pad'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=10,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/swd/val/val.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './work_dirs/rtmdet-ins_m_8xb32-300e_coco'
#
# 02/20 02:31:50 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/20 02:31:50 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage1.1.attention.fc.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage2.1.attention.fc.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.2.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.3.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage3.1.attention.fc.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- backbone.stage4.2.attention.fc.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.1.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.bias:weight_decay=0.0
# 02/20 02:31:51 - mmengine - WARNING - bbox_head.cls_convs.1.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.weight:weight_decay=0.0
# 02/20 02:31:51 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.bias:weight_decay=0.0
# ...
# 02/20 02:53:10 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:53:10 - mmengine - INFO - Epoch(train)  [86][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:03:05  time: 0.3211  data_time: 0.0193  memory: 4282  loss: 0.7142  loss_cls: 0.2401  loss_bbox: 0.2970  loss_mask: 0.1770
# 02/20 02:53:22 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:53:22 - mmengine - INFO - Epoch(train)  [87][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:02:52  time: 0.3211  data_time: 0.0201  memory: 4278  loss: 0.6696  loss_cls: 0.2202  loss_bbox: 0.2826  loss_mask: 0.1668
# 02/20 02:53:37 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:53:37 - mmengine - INFO - Epoch(train)  [88][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:02:39  time: 0.3278  data_time: 0.0193  memory: 4271  loss: 0.6805  loss_cls: 0.2397  loss_bbox: 0.2758  loss_mask: 0.1650
# 02/20 02:53:51 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:53:51 - mmengine - INFO - Epoch(train)  [89][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:02:26  time: 0.3661  data_time: 0.0136  memory: 4271  loss: 0.6661  loss_cls: 0.2250  loss_bbox: 0.2753  loss_mask: 0.1659
# 02/20 02:54:03 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:54:03 - mmengine - INFO - Epoch(train)  [90][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:02:12  time: 0.3232  data_time: 0.0203  memory: 4269  loss: 0.6652  loss_cls: 0.2165  loss_bbox: 0.2789  loss_mask: 0.1699
# 02/20 02:54:03 - mmengine - INFO - Saving checkpoint at 90 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/layers/se_layer.py:158: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/backbones/csp_darknet.py:118: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 02/20 02:54:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.815
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.377
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:54:08 - mmengine - INFO - bbox_mAP_copypaste: 0.560 0.815 0.728 0.377 0.596 -1.000
# 02/20 02:54:08 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.815
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.722
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.403
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.593
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.682
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:54:08 - mmengine - INFO - segm_mAP_copypaste: 0.558 0.815 0.722 0.403 0.593 -1.000
# 02/20 02:54:08 - mmengine - INFO - Epoch(val) [90][12/12]    coco/bbox_mAP: 0.5600  coco/bbox_mAP_50: 0.8150  coco/bbox_mAP_75: 0.7280  coco/bbox_mAP_s: 0.3770  coco/bbox_mAP_m: 0.5960  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.5580  coco/segm_mAP_50: 0.8150  coco/segm_mAP_75: 0.7220  coco/segm_mAP_s: 0.4030  coco/segm_mAP_m: 0.5930  coco/segm_mAP_l: -1.0000  data_time: 0.0265  time: 0.2056
# 02/20 02:54:22 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:54:22 - mmengine - INFO - Epoch(train)  [91][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:01:59  time: 0.3662  data_time: 0.0148  memory: 4241  loss: 0.7163  loss_cls: 0.2512  loss_bbox: 0.2880  loss_mask: 0.1771
# 02/20 02:54:35 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:54:35 - mmengine - INFO - Epoch(train)  [92][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:01:46  time: 0.3322  data_time: 0.0206  memory: 4275  loss: 0.7431  loss_cls: 0.2546  loss_bbox: 0.3007  loss_mask: 0.1878
# 02/20 02:54:49 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:54:49 - mmengine - INFO - Epoch(train)  [93][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:01:33  time: 0.3687  data_time: 0.0122  memory: 4249  loss: 0.7130  loss_cls: 0.2419  loss_bbox: 0.2876  loss_mask: 0.1835
# 02/20 02:55:01 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:55:01 - mmengine - INFO - Epoch(train)  [94][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:01:19  time: 0.3272  data_time: 0.0198  memory: 4237  loss: 0.7161  loss_cls: 0.2383  loss_bbox: 0.2884  loss_mask: 0.1894
# 02/20 02:55:15 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:55:15 - mmengine - INFO - Epoch(train)  [95][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:01:06  time: 0.3606  data_time: 0.0170  memory: 4268  loss: 0.7559  loss_cls: 0.2726  loss_bbox: 0.2984  loss_mask: 0.1848
# 02/20 02:55:15 - mmengine - INFO - Saving checkpoint at 95 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/layers/se_layer.py:158: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/backbones/csp_darknet.py:118: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 02/20 02:55:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.786
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.694
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.585
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:55:20 - mmengine - INFO - bbox_mAP_copypaste: 0.550 0.786 0.694 0.387 0.585 -1.000
# 02/20 02:55:20 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.786
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.713
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.398
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.594
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.701
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:55:20 - mmengine - INFO - segm_mAP_copypaste: 0.551 0.786 0.713 0.398 0.594 -1.000
# 02/20 02:55:20 - mmengine - INFO - Epoch(val) [95][12/12]    coco/bbox_mAP: 0.5500  coco/bbox_mAP_50: 0.7860  coco/bbox_mAP_75: 0.6940  coco/bbox_mAP_s: 0.3870  coco/bbox_mAP_m: 0.5850  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.5510  coco/segm_mAP_50: 0.7860  coco/segm_mAP_75: 0.7130  coco/segm_mAP_s: 0.3980  coco/segm_mAP_m: 0.5940  coco/segm_mAP_l: -1.0000  data_time: 0.0256  time: 0.2103
# 02/20 02:55:32 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:55:32 - mmengine - INFO - Epoch(train)  [96][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:00:53  time: 0.3196  data_time: 0.0215  memory: 4269  loss: 0.7151  loss_cls: 0.2390  loss_bbox: 0.3000  loss_mask: 0.1761
# 02/20 02:55:47 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:55:47 - mmengine - INFO - Epoch(train)  [97][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:00:39  time: 0.3637  data_time: 0.0167  memory: 4342  loss: 0.6805  loss_cls: 0.2225  loss_bbox: 0.2814  loss_mask: 0.1766
# 02/20 02:55:59 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:55:59 - mmengine - INFO - Epoch(train)  [98][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:00:26  time: 0.3198  data_time: 0.0156  memory: 4344  loss: 0.6923  loss_cls: 0.2293  loss_bbox: 0.2835  loss_mask: 0.1795
# 02/20 02:56:13 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:56:13 - mmengine - INFO - Epoch(train)  [99][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:00:13  time: 0.3586  data_time: 0.0170  memory: 4387  loss: 0.7213  loss_cls: 0.2531  loss_bbox: 0.2894  loss_mask: 0.1788
# 02/20 02:56:25 - mmengine - INFO - Exp name: rtmdet-ins_m_8xb32-300e_coco_20250220_023145
# 02/20 02:56:25 - mmengine - INFO - Epoch(train) [100][38/38]  base_lr: 1.0000e-03 lr: 1.0000e-03  eta: 0:00:00  time: 0.3193  data_time: 0.0183  memory: 4352  loss: 0.6565  loss_cls: 0.2250  loss_bbox: 0.2685  loss_mask: 0.1631
# 02/20 02:56:25 - mmengine - INFO - Saving checkpoint at 100 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/layers/se_layer.py:158: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/backbones/csp_darknet.py:118: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# 02/20 02:56:29 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.605
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.839
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.792
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.640
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.727
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:56:29 - mmengine - INFO - bbox_mAP_copypaste: 0.605 0.839 0.792 0.378 0.640 -1.000
# 02/20 02:56:29 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.839
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.744
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.401
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.622
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.563
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.706
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.711
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# 02/20 02:56:30 - mmengine - INFO - segm_mAP_copypaste: 0.589 0.839 0.744 0.401 0.622 -1.000
# 02/20 02:56:30 - mmengine - INFO - Epoch(val) [100][12/12]    coco/bbox_mAP: 0.6050  coco/bbox_mAP_50: 0.8390  coco/bbox_mAP_75: 0.7920  coco/bbox_mAP_s: 0.3780  coco/bbox_mAP_m: 0.6400  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.5890  coco/segm_mAP_50: 0.8390  coco/segm_mAP_75: 0.7440  coco/segm_mAP_s: 0.4010  coco/segm_mAP_m: 0.6220  coco/segm_mAP_l: -1.0000  data_time: 0.0548  time: 0.2256
# 02/20 02:56:30 - mmengine - INFO - The previous best checkpoint /home/tianqi/wslProjects/mmdetection_ty/work_dirs/rtmdet-ins_m_8xb32-300e_coco/best_coco_bbox_mAP_epoch_80.pth is removed
# 02/20 02:56:31 - mmengine - INFO - The best checkpoint with 0.6050 coco/bbox_mAP at 100 epoch is saved to best_coco_bbox_mAP_epoch_100.pth.

# %%
# !python tools/train.py configs/a_swd/cascade-rcnn_r50_fpn_1x_coco.py
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 02/20 12:52:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1995006861
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /home/tianqi/miniconda3/envs/mmcv
#     NVCC: Cuda compilation tools, release 12.4, V12.4.131
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.11.0
#     MMEngine: 0.10.6
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1995006861
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/20 12:52:03 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'data/swd/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, show=False, type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/cascade_rcnn/cascade_mask_rcnn_r50_fpn_1x_coco/cascade_mask_rcnn_r50_fpn_1x_coco_20200203-9d4dcb24.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# metainfo = dict(
#     classes=('swd', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=2,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=2,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=2,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         mask_head=dict(
#             conv_out_channels=256,
#             in_channels=256,
#             loss_mask=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#             num_classes=2,
#             num_convs=4,
#             type='FCNMaskHead'),
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/test.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/swd/',
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/swd/test/test.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=100, type='EpochBasedTrainLoop', val_interval=5)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=4,
#     dataset=dict(
#         ann_file='train/train.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/val.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='data/swd/',
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/swd/val/val.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './work_dirs/cascade-rcnn_r50_fpn_1x_coco'
#
# 02/20 12:52:05 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/20 12:52:05 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/20 12:52:06 - mmengine - INFO - load model from: torchvision://resnet50
# 02/20 12:52:06 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 02/20 12:52:06 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/cascade_rcnn/cascade_mask_rcnn_r50_fpn_1x_coco/cascade_mask_rcnn_r50_fpn_1x_coco_20200203-9d4dcb24.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([3, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([3, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([3, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([3]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([2, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([2]).
# 02/20 12:52:07 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/cascade_rcnn/cascade_mask_rcnn_r50_fpn_1x_coco/cascade_mask_rcnn_r50_fpn_1x_coco_20200203-9d4dcb24.pth
# 02/20 12:52:07 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/20 12:52:07 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/20 12:52:07 - mmengine - INFO - Checkpoints will be saved to /home/tianqi/wslProjects/mmdetection_ty/work_dirs/cascade-rcnn_r50_fpn_1x_coco.
# 02/20 12:52:36 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:52:36 - mmengine - INFO - Epoch(train)   [1][38/38]  lr: 7.5074e-05  eta: 0:47:24  time: 0.7562  data_time: 0.0211  memory: 4756  loss: 2.6314  loss_rpn_cls: 0.0222  loss_rpn_bbox: 0.0038  s0.loss_cls: 0.6787  s0.acc: 96.1914  s0.loss_bbox: 0.0346  s0.loss_mask: 0.6374  s1.loss_cls: 0.4486  s1.acc: 94.9219  s1.loss_bbox: 0.0455  s1.loss_mask: 0.3160  s2.loss_cls: 0.2115  s2.acc: 94.9219  s2.loss_bbox: 0.0249  s2.loss_mask: 0.2084
# 02/20 12:53:06 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:53:06 - mmengine - INFO - Epoch(train)   [2][38/38]  lr: 1.5115e-04  eta: 0:48:09  time: 0.7984  data_time: 0.0208  memory: 4833  loss: 1.4783  loss_rpn_cls: 0.0226  loss_rpn_bbox: 0.0035  s0.loss_cls: 0.1854  s0.acc: 95.8008  s0.loss_bbox: 0.0290  s0.loss_mask: 0.5033  s1.loss_cls: 0.1467  s1.acc: 94.5312  s1.loss_bbox: 0.0406  s1.loss_mask: 0.2741  s2.loss_cls: 0.0774  s2.acc: 95.8008  s2.loss_bbox: 0.0267  s2.loss_mask: 0.1689
# 02/20 12:53:35 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:53:35 - mmengine - INFO - Epoch(train)   [3][38/38]  lr: 2.2723e-04  eta: 0:47:40  time: 0.8158  data_time: 0.0209  memory: 5347  loss: 1.0179  loss_rpn_cls: 0.0150  loss_rpn_bbox: 0.0028  s0.loss_cls: 0.1214  s0.acc: 95.3125  s0.loss_bbox: 0.0243  s0.loss_mask: 0.3230  s1.loss_cls: 0.0889  s1.acc: 92.9688  s1.loss_bbox: 0.0388  s1.loss_mask: 0.2052  s2.loss_cls: 0.0480  s2.acc: 92.0898  s2.loss_bbox: 0.0316  s2.loss_mask: 0.1190
# 02/20 12:54:05 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:54:05 - mmengine - INFO - Epoch(train)   [4][38/38]  lr: 3.0330e-04  eta: 0:47:08  time: 0.7851  data_time: 0.0199  memory: 5213  loss: 0.7548  loss_rpn_cls: 0.0085  loss_rpn_bbox: 0.0017  s0.loss_cls: 0.0964  s0.acc: 95.6055  s0.loss_bbox: 0.0194  s0.loss_mask: 0.2213  s1.loss_cls: 0.0737  s1.acc: 93.0664  s1.loss_bbox: 0.0331  s1.loss_mask: 0.1433  s2.loss_cls: 0.0426  s2.acc: 90.7227  s2.loss_bbox: 0.0313  s2.loss_mask: 0.0834
# 02/20 12:54:34 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:54:34 - mmengine - INFO - Epoch(train)   [5][38/38]  lr: 3.7938e-04  eta: 0:46:37  time: 0.7874  data_time: 0.0205  memory: 5502  loss: 0.5817  loss_rpn_cls: 0.0071  loss_rpn_bbox: 0.0015  s0.loss_cls: 0.0711  s0.acc: 96.9727  s0.loss_bbox: 0.0156  s0.loss_mask: 0.1743  s1.loss_cls: 0.0532  s1.acc: 95.0195  s1.loss_bbox: 0.0284  s1.loss_mask: 0.1075  s2.loss_cls: 0.0336  s2.acc: 95.1172  s2.loss_bbox: 0.0296  s2.loss_mask: 0.0598
# 02/20 12:54:34 - mmengine - INFO - Saving checkpoint at 5 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 02/20 12:54:45 - mmengine - INFO - Epoch(val)   [5][50/58]    eta: 0:00:01  time: 0.1344  data_time: 0.0271  memory: 828
# 02/20 12:54:45 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.462
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.652
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.543
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.288
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.493
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 12:54:45 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.462 | 0.652  | 0.543  | 0.288 | 0.493 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 12:54:45 - mmengine - INFO - bbox_mAP_copypaste: 0.462 0.652 0.543 0.288 0.493 -1.000
# 02/20 12:54:45 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.450
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.652
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.606
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.654
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 12:54:45 - mmengine - INFO -
# +----------+------+--------+--------+-------+-------+-------+
# | category | mAP  | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+------+--------+--------+-------+-------+-------+
# | swd      | 0.45 | 0.652  | 0.606  | 0.289 | 0.502 | nan   |
# +----------+------+--------+--------+-------+-------+-------+
# 02/20 12:54:45 - mmengine - INFO - segm_mAP_copypaste: 0.450 0.652 0.606 0.289 0.502 -1.000
# 02/20 12:54:45 - mmengine - INFO - Epoch(val) [5][58/58]    coco/swd_precision: 0.4500  coco/bbox_mAP: 0.4620  coco/bbox_mAP_50: 0.6520  coco/bbox_mAP_75: 0.5430  coco/bbox_mAP_s: 0.2880  coco/bbox_mAP_m: 0.4930  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4500  coco/segm_mAP_50: 0.6520  coco/segm_mAP_75: 0.6060  coco/segm_mAP_s: 0.2890  coco/segm_mAP_m: 0.5020  coco/segm_mAP_l: -1.0000  data_time: 0.0255  time: 0.1302
# 02/20 12:54:47 - mmengine - INFO - The best checkpoint with 0.4500 coco/swd_precision at 5 epoch is saved to best_coco_swd_precision_epoch_5.pth.
# 02/20 12:55:21 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:55:21 - mmengine - INFO - Epoch(train)   [6][38/38]  lr: 4.5545e-04  eta: 0:46:36  time: 0.8268  data_time: 0.0209  memory: 5501  loss: 0.4756  loss_rpn_cls: 0.0031  loss_rpn_bbox: 0.0012  s0.loss_cls: 0.0510  s0.acc: 99.6094  s0.loss_bbox: 0.0126  s0.loss_mask: 0.1570  s1.loss_cls: 0.0358  s1.acc: 99.1211  s1.loss_bbox: 0.0212  s1.loss_mask: 0.0954  s2.loss_cls: 0.0240  s2.acc: 98.9258  s2.loss_bbox: 0.0230  s2.loss_mask: 0.0513
# 02/20 12:55:51 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:55:51 - mmengine - INFO - Epoch(train)   [7][38/38]  lr: 5.3153e-04  eta: 0:46:16  time: 0.8143  data_time: 0.0206  memory: 5233  loss: 0.4079  loss_rpn_cls: 0.0019  loss_rpn_bbox: 0.0013  s0.loss_cls: 0.0419  s0.acc: 97.8516  s0.loss_bbox: 0.0117  s0.loss_mask: 0.1389  s1.loss_cls: 0.0266  s1.acc: 98.2422  s1.loss_bbox: 0.0191  s1.loss_mask: 0.0834  s2.loss_cls: 0.0186  s2.acc: 98.4375  s2.loss_bbox: 0.0200  s2.loss_mask: 0.0445
# 02/20 12:56:22 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:56:22 - mmengine - INFO - Epoch(train)   [8][38/38]  lr: 6.0761e-04  eta: 0:45:54  time: 0.8203  data_time: -0.0355  memory: 5266  loss: 0.3678  loss_rpn_cls: 0.0016  loss_rpn_bbox: 0.0012  s0.loss_cls: 0.0348  s0.acc: 98.0469  s0.loss_bbox: 0.0107  s0.loss_mask: 0.1297  s1.loss_cls: 0.0201  s1.acc: 97.7539  s1.loss_bbox: 0.0171  s1.loss_mask: 0.0777  s2.loss_cls: 0.0144  s2.acc: 97.6562  s2.loss_bbox: 0.0190  s2.loss_mask: 0.0413
# 02/20 12:56:53 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:56:53 - mmengine - INFO - Epoch(train)   [9][38/38]  lr: 6.8368e-05  eta: 0:45:40  time: 0.8082  data_time: -0.0340  memory: 5355  loss: 0.3408  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0317  s0.acc: 98.8281  s0.loss_bbox: 0.0098  s0.loss_mask: 0.1225  s1.loss_cls: 0.0175  s1.acc: 99.9023  s1.loss_bbox: 0.0153  s1.loss_mask: 0.0738  s2.loss_cls: 0.0124  s2.acc: 99.8047  s2.loss_bbox: 0.0164  s2.loss_mask: 0.0396
# 02/20 12:57:25 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:57:25 - mmengine - INFO - Epoch(train)  [10][38/38]  lr: 7.5976e-05  eta: 0:45:19  time: 0.7692  data_time: 0.0208  memory: 5304  loss: 0.3280  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0302  s0.acc: 99.1211  s0.loss_bbox: 0.0086  s0.loss_mask: 0.1212  s1.loss_cls: 0.0165  s1.acc: 99.6094  s1.loss_bbox: 0.0129  s1.loss_mask: 0.0726  s2.loss_cls: 0.0118  s2.acc: 99.6094  s2.loss_bbox: 0.0134  s2.loss_mask: 0.0390
# 02/20 12:57:25 - mmengine - INFO - Saving checkpoint at 10 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 02/20 12:57:39 - mmengine - INFO - Epoch(val)  [10][50/58]    eta: 0:00:00  time: 0.1202  data_time: 0.0263  memory: 828
# 02/20 12:57:40 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.577
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 12:57:40 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.481 | 0.669  | 0.577  | 0.215 | 0.524 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 12:57:40 - mmengine - INFO - bbox_mAP_copypaste: 0.481 0.669 0.577 0.215 0.524 -1.000
# 02/20 12:57:40 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.224
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 12:57:40 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.476 | 0.669  | 0.636  | 0.224 | 0.519 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 12:57:40 - mmengine - INFO - segm_mAP_copypaste: 0.476 0.669 0.636 0.224 0.519 -1.000
# 02/20 12:57:40 - mmengine - INFO - Epoch(val) [10][58/58]    coco/swd_precision: 0.4760  coco/bbox_mAP: 0.4810  coco/bbox_mAP_50: 0.6690  coco/bbox_mAP_75: 0.5770  coco/bbox_mAP_s: 0.2150  coco/bbox_mAP_m: 0.5240  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4760  coco/segm_mAP_50: 0.6690  coco/segm_mAP_75: 0.6360  coco/segm_mAP_s: 0.2240  coco/segm_mAP_m: 0.5190  coco/segm_mAP_l: -1.0000  data_time: 0.0246  time: 0.1173
# 02/20 12:57:40 - mmengine - INFO - The previous best checkpoint /home/tianqi/wslProjects/mmdetection_ty/work_dirs/cascade-rcnn_r50_fpn_1x_coco/best_coco_swd_precision_epoch_5.pth is removed
# 02/20 12:57:41 - mmengine - INFO - The best checkpoint with 0.4760 coco/swd_precision at 10 epoch is saved to best_coco_swd_precision_epoch_10.pth.
# 02/20 12:58:15 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:58:15 - mmengine - INFO - Epoch(train)  [11][38/38]  lr: 8.3584e-05  eta: 0:44:55  time: 0.7746  data_time: 0.0215  memory: 5364  loss: 0.3300  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0295  s0.acc: 98.6328  s0.loss_bbox: 0.0086  s0.loss_mask: 0.1229  s1.loss_cls: 0.0162  s1.acc: 98.9258  s1.loss_bbox: 0.0134  s1.loss_mask: 0.0735  s2.loss_cls: 0.0114  s2.acc: 98.6328  s2.loss_bbox: 0.0135  s2.loss_mask: 0.0392
# 02/20 12:58:46 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:58:46 - mmengine - INFO - Epoch(train)  [12][38/38]  lr: 9.1191e-06  eta: 0:44:32  time: 0.8268  data_time: 0.0205  memory: 5467  loss: 0.3159  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0282  s0.acc: 98.4375  s0.loss_bbox: 0.0084  s0.loss_mask: 0.1175  s1.loss_cls: 0.0159  s1.acc: 97.4609  s1.loss_bbox: 0.0125  s1.loss_mask: 0.0704  s2.loss_cls: 0.0113  s2.acc: 95.5078  s2.loss_bbox: 0.0125  s2.loss_mask: 0.0376
# 02/20 12:59:17 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:59:17 - mmengine - INFO - Epoch(train)  [13][38/38]  lr: 9.8799e-06  eta: 0:44:06  time: 0.8388  data_time: 0.0209  memory: 5280  loss: 0.3168  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0281  s0.acc: 99.1211  s0.loss_bbox: 0.0081  s0.loss_mask: 0.1192  s1.loss_cls: 0.0153  s1.acc: 99.6094  s1.loss_bbox: 0.0114  s1.loss_mask: 0.0717  s2.loss_cls: 0.0111  s2.acc: 99.1211  s2.loss_bbox: 0.0119  s2.loss_mask: 0.0385
# 02/20 12:59:49 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 12:59:49 - mmengine - INFO - Epoch(train)  [14][38/38]  lr: 1.0000e-05  eta: 0:43:44  time: 0.8002  data_time: 0.0211  memory: 5610  loss: 0.3157  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0276  s0.acc: 99.3164  s0.loss_bbox: 0.0086  s0.loss_mask: 0.1178  s1.loss_cls: 0.0151  s1.acc: 100.0000  s1.loss_bbox: 0.0126  s1.loss_mask: 0.0706  s2.loss_cls: 0.0111  s2.acc: 97.9492  s2.loss_bbox: 0.0126  s2.loss_mask: 0.0380
# 02/20 13:00:23 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:00:23 - mmengine - INFO - Epoch(train)  [15][38/38]  lr: 1.0000e-05  eta: 0:43:32  time: 0.8372  data_time: 0.0215  memory: 5402  loss: 0.3177  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0284  s0.acc: 99.3164  s0.loss_bbox: 0.0082  s0.loss_mask: 0.1186  s1.loss_cls: 0.0150  s1.acc: 97.2656  s1.loss_bbox: 0.0122  s1.loss_mask: 0.0716  s2.loss_cls: 0.0108  s2.acc: 96.4844  s2.loss_bbox: 0.0128  s2.loss_mask: 0.0384
# 02/20 13:00:23 - mmengine - INFO - Saving checkpoint at 15 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 02/20 13:00:34 - mmengine - INFO - Epoch(val)  [15][50/58]    eta: 0:00:00  time: 0.1212  data_time: 0.0247  memory: 828
# 02/20 13:00:35 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.695
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:00:35 - mmengine - INFO -
# +----------+------+--------+--------+-------+-------+-------+
# | category | mAP  | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+------+--------+--------+-------+-------+-------+
# | swd      | 0.48 | 0.67   | 0.579  | 0.226 | 0.523 | nan   |
# +----------+------+--------+--------+-------+-------+-------+
# 02/20 13:00:35 - mmengine - INFO - bbox_mAP_copypaste: 0.480 0.670 0.579 0.226 0.523 -1.000
# 02/20 13:00:35 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.476
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.636
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.233
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.518
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.322
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.688
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:00:35 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.476 | 0.67   | 0.636  | 0.233 | 0.518 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 13:00:35 - mmengine - INFO - segm_mAP_copypaste: 0.476 0.670 0.636 0.233 0.518 -1.000
# 02/20 13:00:35 - mmengine - INFO - Epoch(val) [15][58/58]    coco/swd_precision: 0.4760  coco/bbox_mAP: 0.4800  coco/bbox_mAP_50: 0.6700  coco/bbox_mAP_75: 0.5790  coco/bbox_mAP_s: 0.2260  coco/bbox_mAP_m: 0.5230  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4760  coco/segm_mAP_50: 0.6700  coco/segm_mAP_75: 0.6360  coco/segm_mAP_s: 0.2330  coco/segm_mAP_m: 0.5180  coco/segm_mAP_l: -1.0000  data_time: 0.0231  time: 0.1180
# 02/20 13:01:11 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:01:11 - mmengine - INFO - Epoch(train)  [16][38/38]  lr: 1.0000e-05  eta: 0:43:29  time: 0.8861  data_time: 0.0217  memory: 5374  loss: 0.3220  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0290  s0.acc: 98.4375  s0.loss_bbox: 0.0084  s0.loss_mask: 0.1191  s1.loss_cls: 0.0160  s1.acc: 98.4375  s1.loss_bbox: 0.0129  s1.loss_mask: 0.0715  s2.loss_cls: 0.0112  s2.acc: 98.1445  s2.loss_bbox: 0.0135  s2.loss_mask: 0.0384
# 02/20 13:01:42 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:01:42 - mmengine - INFO - Epoch(train)  [17][38/38]  lr: 1.0000e-05  eta: 0:43:00  time: 0.8335  data_time: 0.0201  memory: 5371  loss: 0.3151  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0279  s0.acc: 99.1211  s0.loss_bbox: 0.0084  s0.loss_mask: 0.1182  s1.loss_cls: 0.0147  s1.acc: 99.6094  s1.loss_bbox: 0.0122  s1.loss_mask: 0.0707  s2.loss_cls: 0.0107  s2.acc: 99.8047  s2.loss_bbox: 0.0126  s2.loss_mask: 0.0380
# 02/20 13:02:14 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:02:14 - mmengine - INFO - Epoch(train)  [18][38/38]  lr: 1.0000e-05  eta: 0:42:31  time: 0.8490  data_time: 0.0200  memory: 5399  loss: 0.3162  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0284  s0.acc: 99.2188  s0.loss_bbox: 0.0080  s0.loss_mask: 0.1187  s1.loss_cls: 0.0149  s1.acc: 98.4375  s1.loss_bbox: 0.0122  s1.loss_mask: 0.0708  s2.loss_cls: 0.0109  s2.acc: 97.8516  s2.loss_bbox: 0.0125  s2.loss_mask: 0.0380
# 02/20 13:02:51 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# ...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.470
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.663
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.513
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:52:04 - mmengine - INFO -
# +----------+------+--------+--------+-------+-------+-------+
# | category | mAP  | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+------+--------+--------+-------+-------+-------+
# | swd      | 0.47 | 0.663  | 0.629  | 0.208 | 0.513 | nan   |
# +----------+------+--------+--------+-------+-------+-------+
# 02/20 13:52:04 - mmengine - INFO - segm_mAP_copypaste: 0.470 0.663 0.629 0.208 0.513 -1.000
# 02/20 13:52:04 - mmengine - INFO - Epoch(val) [90][58/58]    coco/swd_precision: 0.4700  coco/bbox_mAP: 0.4750  coco/bbox_mAP_50: 0.6630  coco/bbox_mAP_75: 0.5610  coco/bbox_mAP_s: 0.2150  coco/bbox_mAP_m: 0.5190  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4700  coco/segm_mAP_50: 0.6630  coco/segm_mAP_75: 0.6290  coco/segm_mAP_s: 0.2080  coco/segm_mAP_m: 0.5130  coco/segm_mAP_l: -1.0000  data_time: 0.0225  time: 0.1347
# 02/20 13:52:39 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:52:39 - mmengine - INFO - Epoch(train)  [91][38/38]  lr: 1.0000e-05  eta: 0:05:39  time: 0.9871  data_time: 0.0205  memory: 5660  loss: 0.2853  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0250  s0.acc: 98.9258  s0.loss_bbox: 0.0078  s0.loss_mask: 0.1083  s1.loss_cls: 0.0123  s1.acc: 99.6094  s1.loss_bbox: 0.0107  s1.loss_mask: 0.0655  s2.loss_cls: 0.0086  s2.acc: 99.0234  s2.loss_bbox: 0.0106  s2.loss_mask: 0.0351
# 02/20 13:53:20 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:53:20 - mmengine - INFO - Epoch(train)  [92][38/38]  lr: 1.0000e-05  eta: 0:05:02  time: 1.0330  data_time: 0.0207  memory: 5356  loss: 0.2842  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0245  s0.acc: 99.0234  s0.loss_bbox: 0.0075  s0.loss_mask: 0.1082  s1.loss_cls: 0.0119  s1.acc: 99.6094  s1.loss_bbox: 0.0105  s1.loss_mask: 0.0658  s2.loss_cls: 0.0088  s2.acc: 99.4141  s2.loss_bbox: 0.0104  s2.loss_mask: 0.0353
# 02/20 13:54:02 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:54:02 - mmengine - INFO - Epoch(train)  [93][38/38]  lr: 1.0000e-05  eta: 0:04:24  time: 1.0498  data_time: 0.0206  memory: 5609  loss: 0.2910  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0252  s0.acc: 99.6094  s0.loss_bbox: 0.0077  s0.loss_mask: 0.1112  s1.loss_cls: 0.0121  s1.acc: 99.5117  s1.loss_bbox: 0.0110  s1.loss_mask: 0.0669  s2.loss_cls: 0.0086  s2.acc: 99.6094  s2.loss_bbox: 0.0109  s2.loss_mask: 0.0359
# 02/20 13:54:37 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:54:37 - mmengine - INFO - Epoch(train)  [94][38/38]  lr: 1.0000e-05  eta: 0:03:46  time: 1.0144  data_time: 0.0203  memory: 5600  loss: 0.2841  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0233  s0.acc: 99.0234  s0.loss_bbox: 0.0070  s0.loss_mask: 0.1094  s1.loss_cls: 0.0114  s1.acc: 99.1211  s1.loss_bbox: 0.0102  s1.loss_mask: 0.0669  s2.loss_cls: 0.0082  s2.acc: 97.9492  s2.loss_bbox: 0.0101  s2.loss_mask: 0.0359
# 02/20 13:55:19 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:55:19 - mmengine - INFO - Epoch(train)  [95][38/38]  lr: 1.0000e-05  eta: 0:03:09  time: 1.0885  data_time: 0.0205  memory: 5441  loss: 0.2816  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0240  s0.acc: 99.3164  s0.loss_bbox: 0.0071  s0.loss_mask: 0.1080  s1.loss_cls: 0.0117  s1.acc: 99.9023  s1.loss_bbox: 0.0101  s1.loss_mask: 0.0653  s2.loss_cls: 0.0083  s2.acc: 99.7070  s2.loss_bbox: 0.0102  s2.loss_mask: 0.0352
# 02/20 13:55:19 - mmengine - INFO - Saving checkpoint at 95 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 02/20 13:55:29 - mmengine - INFO - Epoch(val)  [95][50/58]    eta: 0:00:01  time: 0.1448  data_time: 0.0236  memory: 828
# 02/20 13:55:30 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.661
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.560
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:55:30 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.473 | 0.661  | 0.56   | 0.215 | 0.517 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 13:55:30 - mmengine - INFO - bbox_mAP_copypaste: 0.473 0.661 0.560 0.215 0.517 -1.000
# 02/20 13:55:30 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.661
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:55:30 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.469 | 0.661  | 0.627  | 0.222 | 0.511 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 13:55:30 - mmengine - INFO - segm_mAP_copypaste: 0.469 0.661 0.627 0.222 0.511 -1.000
# 02/20 13:55:30 - mmengine - INFO - Epoch(val) [95][58/58]    coco/swd_precision: 0.4690  coco/bbox_mAP: 0.4730  coco/bbox_mAP_50: 0.6610  coco/bbox_mAP_75: 0.5600  coco/bbox_mAP_s: 0.2150  coco/bbox_mAP_m: 0.5170  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4690  coco/segm_mAP_50: 0.6610  coco/segm_mAP_75: 0.6270  coco/segm_mAP_s: 0.2220  coco/segm_mAP_m: 0.5110  coco/segm_mAP_l: -1.0000  data_time: 0.0222  time: 0.1411
# 02/20 13:56:04 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:56:04 - mmengine - INFO - Epoch(train)  [96][38/38]  lr: 1.0000e-05  eta: 0:02:31  time: 0.9445  data_time: 0.0203  memory: 5412  loss: 0.2806  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0237  s0.acc: 97.7539  s0.loss_bbox: 0.0072  s0.loss_mask: 0.1083  s1.loss_cls: 0.0112  s1.acc: 98.1445  s1.loss_bbox: 0.0101  s1.loss_mask: 0.0652  s2.loss_cls: 0.0081  s2.acc: 98.0469  s2.loss_bbox: 0.0106  s2.loss_mask: 0.0350
# 02/20 13:56:37 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:56:37 - mmengine - INFO - Epoch(train)  [97][38/38]  lr: 1.0000e-05  eta: 0:01:53  time: 0.8971  data_time: 0.0201  memory: 5417  loss: 0.2857  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0010  s0.loss_cls: 0.0253  s0.acc: 97.3633  s0.loss_bbox: 0.0078  s0.loss_mask: 0.1091  s1.loss_cls: 0.0117  s1.acc: 98.4375  s1.loss_bbox: 0.0106  s1.loss_mask: 0.0657  s2.loss_cls: 0.0084  s2.acc: 97.7539  s2.loss_bbox: 0.0106  s2.loss_mask: 0.0350
# 02/20 13:57:25 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:57:25 - mmengine - INFO - Epoch(train)  [98][38/38]  lr: 1.0000e-05  eta: 0:01:15  time: 1.1371  data_time: 0.0208  memory: 5673  loss: 0.2827  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0237  s0.acc: 99.3164  s0.loss_bbox: 0.0077  s0.loss_mask: 0.1083  s1.loss_cls: 0.0112  s1.acc: 99.0234  s1.loss_bbox: 0.0106  s1.loss_mask: 0.0655  s2.loss_cls: 0.0083  s2.acc: 98.8281  s2.loss_bbox: 0.0108  s2.loss_mask: 0.0352
# 02/20 13:58:02 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:58:02 - mmengine - INFO - Epoch(train)  [99][38/38]  lr: 1.0000e-05  eta: 0:00:37  time: 1.0483  data_time: 0.0212  memory: 5312  loss: 0.2792  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0241  s0.acc: 99.3164  s0.loss_bbox: 0.0074  s0.loss_mask: 0.1072  s1.loss_cls: 0.0116  s1.acc: 99.7070  s1.loss_bbox: 0.0100  s1.loss_mask: 0.0645  s2.loss_cls: 0.0082  s2.acc: 99.3164  s2.loss_bbox: 0.0101  s2.loss_mask: 0.0346
# 02/20 13:58:43 - mmengine - INFO - Exp name: cascade-rcnn_r50_fpn_1x_coco_20250220_125202
# 02/20 13:58:43 - mmengine - INFO - Epoch(train) [100][38/38]  lr: 1.0000e-05  eta: 0:00:00  time: 1.0304  data_time: 0.0210  memory: 5527  loss: 0.2770  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0229  s0.acc: 99.4141  s0.loss_bbox: 0.0071  s0.loss_mask: 0.1073  s1.loss_cls: 0.0106  s1.acc: 99.9023  s1.loss_bbox: 0.0099  s1.loss_mask: 0.0651  s2.loss_cls: 0.0079  s2.acc: 99.6094  s2.loss_bbox: 0.0101  s2.loss_mask: 0.0348
# 02/20 13:58:43 - mmengine - INFO - Saving checkpoint at 100 epochs
# /home/tianqi/wslProjects/mmdetection_ty/mmdet/models/roi_heads/mask_heads/fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 02/20 13:58:51 - mmengine - INFO - Epoch(val) [100][50/58]    eta: 0:00:01  time: 0.1307  data_time: 0.0240  memory: 828
# 02/20 13:58:52 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.474
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.662
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.215
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.628
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:58:52 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.474 | 0.662  | 0.559  | 0.215 | 0.517 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 13:58:52 - mmengine - INFO - bbox_mAP_copypaste: 0.474 0.662 0.559 0.215 0.517 -1.000
# 02/20 13:58:52 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.469
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.662
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.512
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 13:58:52 - mmengine - INFO -
# +----------+-------+--------+--------+-------+-------+-------+
# | category | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------+-------+--------+--------+-------+-------+-------+
# | swd      | 0.469 | 0.662  | 0.628  | 0.222 | 0.512 | nan   |
# +----------+-------+--------+--------+-------+-------+-------+
# 02/20 13:58:52 - mmengine - INFO - segm_mAP_copypaste: 0.469 0.662 0.628 0.222 0.512 -1.000
# 02/20 13:58:52 - mmengine - INFO - Epoch(val) [100][58/58]    coco/swd_precision: 0.4690  coco/bbox_mAP: 0.4740  coco/bbox_mAP_50: 0.6620  coco/bbox_mAP_75: 0.5590  coco/bbox_mAP_s: 0.2150  coco/bbox_mAP_m: 0.5170  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4690  coco/segm_mAP_50: 0.6620  coco/segm_mAP_75: 0.6280  coco/segm_mAP_s: 0.2220  coco/segm_mAP_m: 0.5120  coco/segm_mAP_l: -1.0000  data_time: 0.0278  time: 0.1323

# %%
# !python tools/train.py configs/a_swd/mask2former_r50_8xb2-lsj-50e_coco.py
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 02/20 03:00:04 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 310885934
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /home/tianqi/miniconda3/envs/mmcv
#     NVCC: Cuda compilation tools, release 12.4, V12.4.131
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.11.0
#     MMEngine: 0.10.6
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 310885934
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/20 03:00:04 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# batch_augments = [
#     dict(
#         img_pad_value=0,
#         mask_pad_value=0,
#         pad_mask=True,
#         pad_seg=False,
#         size=(
#             640,
#             640,
#         ),
#         type='BatchFixedSizePad'),
# ]
# data_preprocessor = dict(
#     batch_augments=[
#         dict(
#             img_pad_value=0,
#             mask_pad_value=0,
#             pad_mask=True,
#             pad_seg=False,
#             size=(
#                 640,
#                 640,
#             ),
#             type='BatchFixedSizePad'),
#     ],
#     bgr_to_rgb=True,
#     mask_pad_value=0,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_mask=True,
#     pad_seg=False,
#     pad_size_divisor=32,
#     seg_pad_value=255,
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='DetDataPreprocessor')
# data_root = 'data/swd/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=5000,
#         max_keep_ckpts=3,
#         save_best='auto',
#         save_last=True,
#         type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, show=False, type='DetVisualizationHook'))
# default_scope = 'mmdet'
# dynamic_intervals = [
#     (
#         365001,
#         368750,
#     ),
# ]
# embed_multi = dict(decay_mult=0.0, lr_mult=1.0)
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# image_size = (
#     640,
#     640,
# )
# interval = 5000
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmdetection/v3.0/mask2former/mask2former_r50_8xb2-lsj-50e_coco/mask2former_r50_8xb2-lsj-50e_coco_20220506_191028-41b088b6.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False, type='LogProcessor', window_size=50)
# max_iters = 368750
# metainfo = dict(
#     classes=('swd', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=-1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=False, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         batch_augments=[
#             dict(
#                 img_pad_value=0,
#                 mask_pad_value=0,
#                 pad_mask=True,
#                 pad_seg=False,
#                 size=(
#                     640,
#                     640,
#                 ),
#                 type='BatchFixedSizePad'),
#         ],
#         bgr_to_rgb=True,
#         mask_pad_value=0,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_seg=False,
#         pad_size_divisor=32,
#         seg_pad_value=255,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     init_cfg=None,
#     panoptic_fusion_head=dict(
#         init_cfg=None,
#         loss_panoptic=None,
#         num_stuff_classes=0,
#         num_things_classes=1,
#         type='MaskFormerFusionHead'),
#     panoptic_head=dict(
#         enforce_decoder_input_project=False,
#         feat_channels=256,
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         loss_cls=dict(
#             class_weight=[
#                 1.0,
#                 0.1,
#             ],
#             loss_weight=2.0,
#             reduction='mean',
#             type='CrossEntropyLoss',
#             use_sigmoid=False),
#         loss_dice=dict(
#             activate=True,
#             eps=1.0,
#             loss_weight=5.0,
#             naive_dice=True,
#             reduction='mean',
#             type='DiceLoss',
#             use_sigmoid=True),
#         loss_mask=dict(
#             loss_weight=5.0,
#             reduction='mean',
#             type='CrossEntropyLoss',
#             use_sigmoid=True),
#         num_queries=100,
#         num_stuff_classes=0,
#         num_things_classes=1,
#         num_transformer_feat_level=3,
#         out_channels=256,
#         pixel_decoder=dict(
#             act_cfg=dict(type='ReLU'),
#             encoder=dict(
#                 layer_cfg=dict(
#                     ffn_cfg=dict(
#                         act_cfg=dict(inplace=True, type='ReLU'),
#                         embed_dims=256,
#                         feedforward_channels=1024,
#                         ffn_drop=0.0,
#                         num_fcs=2),
#                     self_attn_cfg=dict(
#                         batch_first=True,
#                         dropout=0.0,
#                         embed_dims=256,
#                         num_heads=8,
#                         num_levels=3,
#                         num_points=4)),
#                 num_layers=6),
#             norm_cfg=dict(num_groups=32, type='GN'),
#             num_outs=3,
#             positional_encoding=dict(normalize=True, num_feats=128),
#             type='MSDeformAttnPixelDecoder'),
#         positional_encoding=dict(normalize=True, num_feats=128),
#         strides=[
#             4,
#             8,
#             16,
#             32,
#         ],
#         transformer_decoder=dict(
#             init_cfg=None,
#             layer_cfg=dict(
#                 cross_attn_cfg=dict(
#                     batch_first=True, dropout=0.0, embed_dims=256,
#                     num_heads=8),
#                 ffn_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     embed_dims=256,
#                     feedforward_channels=2048,
#                     ffn_drop=0.0,
#                     num_fcs=2),
#                 self_attn_cfg=dict(
#                     batch_first=True, dropout=0.0, embed_dims=256,
#                     num_heads=8)),
#             num_layers=9,
#             return_intermediate=True),
#         type='Mask2FormerHead'),
#     test_cfg=dict(
#         filter_low_score=True,
#         instance_on=True,
#         iou_thr=0.8,
#         max_per_image=100,
#         panoptic_on=False,
#         semantic_on=False),
#     train_cfg=dict(
#         assigner=dict(
#             match_costs=[
#                 dict(type='ClassificationCost', weight=2.0),
#                 dict(
#                     type='CrossEntropyLossCost', use_sigmoid=True, weight=5.0),
#                 dict(eps=1.0, pred_act=True, type='DiceCost', weight=5.0),
#             ],
#             type='HungarianAssigner'),
#         importance_sample_ratio=0.75,
#         num_points=12544,
#         oversample_ratio=3.0,
#         sampler=dict(type='MaskPseudoSampler')),
#     type='Mask2Former')
# num_classes = 1
# num_stuff_classes = 0
# num_things_classes = 1
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=0.01, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ),
#         eps=1e-08,
#         lr=0.0001,
#         type='AdamW',
#         weight_decay=0.05),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             backbone=dict(decay_mult=1.0, lr_mult=0.1),
#             level_embed=dict(decay_mult=0.0, lr_mult=1.0),
#             query_embed=dict(decay_mult=0.0, lr_mult=1.0),
#             query_feat=dict(decay_mult=0.0, lr_mult=1.0)),
#         norm_decay_mult=0.0),
#     type='OptimWrapper')
# param_scheduler = dict(
#     begin=0,
#     by_epoch=False,
#     end=368750,
#     gamma=0.1,
#     milestones=[
#         327778,
#         355092,
#     ],
#     type='MultiStepLR')
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/test.json',
#         backend_args=None,
#         data_prefix=dict(img='test/', seg='annotations/panoptic_val2017/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=False),
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, to_float32=True, type='LoadImageFromFile'),
#             dict(keep_ratio=False, scale=(
#                 640,
#                 640,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/swd/test/test.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, to_float32=True, type='LoadImageFromFile'),
#     dict(keep_ratio=False, scale=(
#         640,
#         640,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=100, type='EpochBasedTrainLoop', val_interval=5)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/train.json',
#         backend_args=None,
#         data_prefix=dict(img='train/', seg='annotations/panoptic_train2017/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, to_float32=True, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.1,
#                     2.0,
#                 ),
#                 resize_type='Resize',
#                 scale=(
#                     640,
#                     640,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 allow_negative_crop=True,
#                 crop_size=(
#                     640,
#                     640,
#                 ),
#                 crop_type='absolute',
#                 recompute_bbox=True,
#                 type='RandomCrop'),
#             dict(
#                 by_mask=True,
#                 min_gt_bbox_wh=(
#                     1e-05,
#                     1e-05,
#                 ),
#                 type='FilterAnnotations'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, to_float32=True, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.1,
#             2.0,
#         ),
#         resize_type='Resize',
#         scale=(
#             640,
#             640,
#         ),
#         type='RandomResize'),
#     dict(
#         allow_negative_crop=True,
#         crop_size=(
#             640,
#             640,
#         ),
#         crop_type='absolute',
#         recompute_bbox=True,
#         type='RandomCrop'),
#     dict(
#         by_mask=True,
#         min_gt_bbox_wh=(
#             1e-05,
#             1e-05,
#         ),
#         type='FilterAnnotations'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/val.json',
#         backend_args=None,
#         data_prefix=dict(img='val/', seg='annotations/panoptic_val2017/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=False),
#         metainfo=dict(classes=('swd', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         pipeline=[
#             dict(backend_args=None, to_float32=True, type='LoadImageFromFile'),
#             dict(keep_ratio=False, scale=(
#                 640,
#                 640,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/swd/val/val.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './work_dirs/mask2former_r50_8xb2-lsj-50e_coco'
#
# 02/20 03:00:06 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/20 03:00:06 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.0.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.0.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.0.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.0.downsample.0.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.downsample.1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.0.downsample.1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.1.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.1.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer1.2.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer1.2.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.0.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.0.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.0.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.0.downsample.0.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.downsample.1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.0.downsample.1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.1.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.1.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.2.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.2.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer2.3.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer2.3.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.0.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.0.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.0.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.0.downsample.0.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.downsample.1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.0.downsample.1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.1.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.1.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.2.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.2.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.3.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.3.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.4.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.4.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn2.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv3.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv3.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv3.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer3.5.conv3.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn3.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer3.5.bn3.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv1.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv1.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv1.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv1.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer4.0.bn1.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer4.0.bn1.bias is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv2.weight:lr=1e-05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv2.weight:weight_decay=0.05
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv2.weight:lr_mult=0.1
# 02/20 03:00:06 - mmengine - INFO - paramwise_options -- backbone.layer4.0.conv2.weight:decay_mult=1.0
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer4.0.bn2.weight is skipped since its requires_grad=False
# 02/20 03:00:06 - mmengine - WARNING - backbone.layer4.0.bn2.bias is skipped since its requires_grad=False
# ...
# 02/20 03:58:19 - mmengine - INFO - Iter(train) [6800/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:05:35  time: 0.4652  data_time: 0.0107  memory: 4112  grad_norm: 110.7060  loss: 5.4722  loss_cls: 0.0552  loss_mask: 0.0158  loss_dice: 0.3997  d0.loss_cls: 0.3066  d0.loss_mask: 0.0172  d0.loss_dice: 0.4521  d1.loss_cls: 0.0509  d1.loss_mask: 0.0166  d1.loss_dice: 0.4491  d2.loss_cls: 0.0973  d2.loss_mask: 0.0179  d2.loss_dice: 0.3628  d3.loss_cls: 0.0487  d3.loss_mask: 0.0179  d3.loss_dice: 0.4826  d4.loss_cls: 0.0593  d4.loss_mask: 0.0178  d4.loss_dice: 0.4730  d5.loss_cls: 0.0576  d5.loss_mask: 0.0188  d5.loss_dice: 0.4783  d6.loss_cls: 0.0565  d6.loss_mask: 0.0186  d6.loss_dice: 0.4793  d7.loss_cls: 0.0777  d7.loss_mask: 0.0160  d7.loss_dice: 0.4602  d8.loss_cls: 0.0605  d8.loss_mask: 0.0149  d8.loss_dice: 0.3932
# 02/20 03:58:30 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 03:58:56 - mmengine - INFO - Iter(train) [6875/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:04:59  time: 0.5096  data_time: 0.0107  memory: 4112  grad_norm: 92.6557  loss: 5.5778  loss_cls: 0.0323  loss_mask: 0.0177  loss_dice: 0.4492  d0.loss_cls: 0.2507  d0.loss_mask: 0.0195  d0.loss_dice: 0.4840  d1.loss_cls: 0.0167  d1.loss_mask: 0.0178  d1.loss_dice: 0.5149  d2.loss_cls: 0.0298  d2.loss_mask: 0.0198  d2.loss_dice: 0.5004  d3.loss_cls: 0.0271  d3.loss_mask: 0.0179  d3.loss_dice: 0.4925  d4.loss_cls: 0.0321  d4.loss_mask: 0.0168  d4.loss_dice: 0.4396  d5.loss_cls: 0.0425  d5.loss_mask: 0.0183  d5.loss_dice: 0.4921  d6.loss_cls: 0.0190  d6.loss_mask: 0.0200  d6.loss_dice: 0.5217  d7.loss_cls: 0.0192  d7.loss_mask: 0.0183  d7.loss_dice: 0.5283  d8.loss_cls: 0.0330  d8.loss_mask: 0.0183  d8.loss_dice: 0.4679
# 02/20 03:59:06 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 03:59:31 - mmengine - INFO - Iter(train) [6950/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:04:23  time: 0.5081  data_time: 0.0107  memory: 4112  grad_norm: 136.1313  loss: 6.2591  loss_cls: 0.0194  loss_mask: 0.0224  loss_dice: 0.5395  d0.loss_cls: 0.2801  d0.loss_mask: 0.0210  d0.loss_dice: 0.5133  d1.loss_cls: 0.0420  d1.loss_mask: 0.0183  d1.loss_dice: 0.5555  d2.loss_cls: 0.0235  d2.loss_mask: 0.0198  d2.loss_dice: 0.5389  d3.loss_cls: 0.0185  d3.loss_mask: 0.0230  d3.loss_dice: 0.5816  d4.loss_cls: 0.0125  d4.loss_mask: 0.0222  d4.loss_dice: 0.5169  d5.loss_cls: 0.0224  d5.loss_mask: 0.0230  d5.loss_dice: 0.5921  d6.loss_cls: 0.0268  d6.loss_mask: 0.0218  d6.loss_dice: 0.6118  d7.loss_cls: 0.0130  d7.loss_mask: 0.0220  d7.loss_dice: 0.5561  d8.loss_cls: 0.0316  d8.loss_mask: 0.0230  d8.loss_dice: 0.5469
# 02/20 03:59:42 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 03:59:55 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:00:06 - mmengine - INFO - Iter(train) [7025/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:03:47  time: 0.4707  data_time: 0.0105  memory: 4112  grad_norm: 105.5657  loss: 5.7860  loss_cls: 0.0360  loss_mask: 0.0219  loss_dice: 0.5406  d0.loss_cls: 0.2147  d0.loss_mask: 0.0220  d0.loss_dice: 0.4764  d1.loss_cls: 0.0292  d1.loss_mask: 0.0206  d1.loss_dice: 0.4831  d2.loss_cls: 0.0356  d2.loss_mask: 0.0217  d2.loss_dice: 0.5140  d3.loss_cls: 0.0486  d3.loss_mask: 0.0218  d3.loss_dice: 0.5542  d4.loss_cls: 0.0445  d4.loss_mask: 0.0204  d4.loss_dice: 0.4927  d5.loss_cls: 0.0496  d5.loss_mask: 0.0208  d5.loss_dice: 0.4943  d6.loss_cls: 0.0380  d6.loss_mask: 0.0196  d6.loss_dice: 0.4782  d7.loss_cls: 0.0397  d7.loss_mask: 0.0212  d7.loss_dice: 0.5121  d8.loss_cls: 0.0349  d8.loss_mask: 0.0214  d8.loss_dice: 0.4583
# 02/20 04:00:19 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:00:42 - mmengine - INFO - Iter(train) [7100/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:03:11  time: 0.4667  data_time: 0.0105  memory: 4112  grad_norm: 125.6575  loss: 4.2798  loss_cls: 0.0009  loss_mask: 0.0176  loss_dice: 0.4017  d0.loss_cls: 0.1632  d0.loss_mask: 0.0189  d0.loss_dice: 0.4505  d1.loss_cls: 0.0171  d1.loss_mask: 0.0169  d1.loss_dice: 0.3875  d2.loss_cls: 0.0160  d2.loss_mask: 0.0161  d2.loss_dice: 0.3603  d3.loss_cls: 0.0025  d3.loss_mask: 0.0163  d3.loss_dice: 0.3874  d4.loss_cls: 0.0007  d4.loss_mask: 0.0154  d4.loss_dice: 0.3701  d5.loss_cls: 0.0006  d5.loss_mask: 0.0162  d5.loss_dice: 0.3607  d6.loss_cls: 0.0129  d6.loss_mask: 0.0161  d6.loss_dice: 0.3802  d7.loss_cls: 0.0004  d7.loss_mask: 0.0167  d7.loss_dice: 0.3879  d8.loss_cls: 0.0004  d8.loss_mask: 0.0157  d8.loss_dice: 0.4127
# 02/20 04:00:55 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:01:03 - mmengine - INFO - Iter(val) [50/58]    eta: 0:00:01  time: 0.1723  data_time: 0.0208  memory: 4112
# 02/20 04:01:05 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.489
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.484
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.619
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:01:05 - mmengine - INFO - bbox_mAP_copypaste: 0.411 0.562 0.489 0.255 0.484 -1.000
# 02/20 04:01:05 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.437
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.615
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.616
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.667
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:01:06 - mmengine - INFO - segm_mAP_copypaste: 0.437 0.615 0.550 0.279 0.486 -1.000
# 02/20 04:01:06 - mmengine - INFO - Iter(val) [58/58]    coco/bbox_mAP: 0.4110  coco/bbox_mAP_50: 0.5620  coco/bbox_mAP_75: 0.4890  coco/bbox_mAP_s: 0.2550  coco/bbox_mAP_m: 0.4840  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.4370  coco/segm_mAP_50: 0.6150  coco/segm_mAP_75: 0.5500  coco/segm_mAP_s: 0.2790  coco/segm_mAP_m: 0.4860  coco/segm_mAP_l: -1.0000  data_time: 0.0198  time: 0.1772
# 02/20 04:01:31 - mmengine - INFO - Iter(train) [7175/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:02:35  time: 0.5114  data_time: 0.0104  memory: 4112  grad_norm: 156.1364  loss: 5.3213  loss_cls: 0.0610  loss_mask: 0.0165  loss_dice: 0.4105  d0.loss_cls: 0.2971  d0.loss_mask: 0.0173  d0.loss_dice: 0.4512  d1.loss_cls: 0.0928  d1.loss_mask: 0.0155  d1.loss_dice: 0.4352  d2.loss_cls: 0.0686  d2.loss_mask: 0.0167  d2.loss_dice: 0.4339  d3.loss_cls: 0.0409  d3.loss_mask: 0.0166  d3.loss_dice: 0.4670  d4.loss_cls: 0.0511  d4.loss_mask: 0.0174  d4.loss_dice: 0.4571  d5.loss_cls: 0.0451  d5.loss_mask: 0.0170  d5.loss_dice: 0.4048  d6.loss_cls: 0.0280  d6.loss_mask: 0.0169  d6.loss_dice: 0.4460  d7.loss_cls: 0.0519  d7.loss_mask: 0.0165  d7.loss_dice: 0.4199  d8.loss_cls: 0.0395  d8.loss_mask: 0.0161  d8.loss_dice: 0.4535
# 02/20 04:01:42 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:02:05 - mmengine - INFO - Iter(train) [7250/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:01:59  time: 0.4678  data_time: 0.0107  memory: 4112  grad_norm: 105.7425  loss: 6.4967  loss_cls: 0.0750  loss_mask: 0.0207  loss_dice: 0.5200  d0.loss_cls: 0.2363  d0.loss_mask: 0.0238  d0.loss_dice: 0.6399  d1.loss_cls: 0.0757  d1.loss_mask: 0.0187  d1.loss_dice: 0.5239  d2.loss_cls: 0.0875  d2.loss_mask: 0.0232  d2.loss_dice: 0.4481  d3.loss_cls: 0.0748  d3.loss_mask: 0.0235  d3.loss_dice: 0.5428  d4.loss_cls: 0.0779  d4.loss_mask: 0.0246  d4.loss_dice: 0.5522  d5.loss_cls: 0.0782  d5.loss_mask: 0.0234  d5.loss_dice: 0.5519  d6.loss_cls: 0.0808  d6.loss_mask: 0.0227  d6.loss_dice: 0.5636  d7.loss_cls: 0.0724  d7.loss_mask: 0.0205  d7.loss_dice: 0.4581  d8.loss_cls: 0.0739  d8.loss_mask: 0.0208  d8.loss_dice: 0.5419
# 02/20 04:02:18 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:02:41 - mmengine - INFO - Iter(train) [7325/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:01:23  time: 0.4668  data_time: 0.0110  memory: 4112  grad_norm: 101.5118  loss: 4.5539  loss_cls: 0.0011  loss_mask: 0.0194  loss_dice: 0.4302  d0.loss_cls: 0.3213  d0.loss_mask: 0.0198  d0.loss_dice: 0.3671  d1.loss_cls: 0.0131  d1.loss_mask: 0.0172  d1.loss_dice: 0.3814  d2.loss_cls: 0.0018  d2.loss_mask: 0.0174  d2.loss_dice: 0.3920  d3.loss_cls: 0.0014  d3.loss_mask: 0.0178  d3.loss_dice: 0.4321  d4.loss_cls: 0.0006  d4.loss_mask: 0.0171  d4.loss_dice: 0.3995  d5.loss_cls: 0.0120  d5.loss_mask: 0.0179  d5.loss_dice: 0.4189  d6.loss_cls: 0.0007  d6.loss_mask: 0.0170  d6.loss_dice: 0.3952  d7.loss_cls: 0.0010  d7.loss_mask: 0.0188  d7.loss_dice: 0.3943  d8.loss_cls: 0.0010  d8.loss_mask: 0.0184  d8.loss_dice: 0.4083
# 02/20 04:02:54 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:03:18 - mmengine - INFO - Iter(train) [7400/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:00:47  time: 0.4724  data_time: 0.0109  memory: 4112  grad_norm: 120.0625  loss: 5.9840  loss_cls: 0.0091  loss_mask: 0.0215  loss_dice: 0.5551  d0.loss_cls: 0.2981  d0.loss_mask: 0.0244  d0.loss_dice: 0.6127  d1.loss_cls: 0.0309  d1.loss_mask: 0.0225  d1.loss_dice: 0.4930  d2.loss_cls: 0.0122  d2.loss_mask: 0.0231  d2.loss_dice: 0.5063  d3.loss_cls: 0.0192  d3.loss_mask: 0.0234  d3.loss_dice: 0.5571  d4.loss_cls: 0.0084  d4.loss_mask: 0.0199  d4.loss_dice: 0.5390  d5.loss_cls: 0.0071  d5.loss_mask: 0.0214  d5.loss_dice: 0.4757  d6.loss_cls: 0.0078  d6.loss_mask: 0.0214  d6.loss_dice: 0.5217  d7.loss_cls: 0.0091  d7.loss_mask: 0.0226  d7.loss_dice: 0.5306  d8.loss_cls: 0.0093  d8.loss_mask: 0.0220  d8.loss_dice: 0.5594
# 02/20 04:03:30 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:03:54 - mmengine - INFO - Iter(train) [7475/7500]  base_lr: 1.0000e-04 lr: 1.0000e-05  eta: 0:00:11  time: 0.4670  data_time: 0.0109  memory: 4112  grad_norm: 149.1455  loss: 5.3712  loss_cls: 0.0511  loss_mask: 0.0185  loss_dice: 0.4505  d0.loss_cls: 0.2735  d0.loss_mask: 0.0211  d0.loss_dice: 0.5510  d1.loss_cls: 0.0452  d1.loss_mask: 0.0185  d1.loss_dice: 0.4201  d2.loss_cls: 0.0284  d2.loss_mask: 0.0190  d2.loss_dice: 0.4291  d3.loss_cls: 0.0554  d3.loss_mask: 0.0198  d3.loss_dice: 0.4640  d4.loss_cls: 0.0428  d4.loss_mask: 0.0182  d4.loss_dice: 0.3731  d5.loss_cls: 0.0476  d5.loss_mask: 0.0198  d5.loss_dice: 0.4385  d6.loss_cls: 0.0339  d6.loss_mask: 0.0189  d6.loss_dice: 0.5065  d7.loss_cls: 0.0432  d7.loss_mask: 0.0197  d7.loss_dice: 0.4316  d8.loss_cls: 0.0517  d8.loss_mask: 0.0194  d8.loss_dice: 0.4408
# 02/20 04:04:04 - mmengine - INFO - Exp name: mask2former_r50_8xb2-lsj-50e_coco_20250220_030003
# 02/20 04:04:04 - mmengine - INFO - Saving checkpoint at 7500 iterations
# 02/20 04:04:24 - mmengine - INFO - Iter(val) [50/58]    eta: 0:00:01  time: 0.2391  data_time: 0.0233  memory: 4112
# 02/20 04:04:26 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.501
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.433
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.139
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.399
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:04:26 - mmengine - INFO - bbox_mAP_copypaste: 0.334 0.501 0.433 0.139 0.399 -1.000
# 02/20 04:04:26 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.326
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.532
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.380
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.369
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.558
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.278
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:04:27 - mmengine - INFO - segm_mAP_copypaste: 0.326 0.532 0.380 0.170 0.369 -1.000
# 02/20 04:04:27 - mmengine - INFO - Iter(val) [58/58]    coco/bbox_mAP: 0.3340  coco/bbox_mAP_50: 0.5010  coco/bbox_mAP_75: 0.4330  coco/bbox_mAP_s: 0.1390  coco/bbox_mAP_m: 0.3990  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.3260  coco/segm_mAP_50: 0.5320  coco/segm_mAP_75: 0.3800  coco/segm_mAP_s: 0.1700  coco/segm_mAP_m: 0.3690  coco/segm_mAP_l: -1.0000  data_time: 0.0280  time: 0.2425

# %%
# !python tools/train.py configs/a_swd/queryinst_r50_fpn_1x_coco.py
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# 02/20 04:04:32 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.16 (main, Dec 11 2024, 16:24:50) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1218543231
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /home/tianqi/miniconda3/envs/mmcv
#     NVCC: Cuda compilation tools, release 12.4, V12.4.131
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.6.0+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2024.2-Product Build 20240605 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.4
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 90.1
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, COMMIT_SHA=2236df1770800ffea5697b11b0bb0d910b2e59e1, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.6.0, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.21.0+cu124
#     OpenCV: 4.11.0
#     MMEngine: 0.10.6
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1218543231
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/20 04:04:33 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'data/swd/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=50, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(draw=True, show=False, type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/queryinst/queryinst_r50_fpn_1x_coco/queryinst_r50_fpn_1x_coco_20210907_084916-5a8f1998.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# metainfo = dict(
#     classes=('swd', ),
#     palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#         (
#             190,
#             255,
#             0,
#         ),
#         (
#             153,
#             153,
#             153,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         depth=50,
#         frozen_stages=1,
#         init_cfg=dict(checkpoint='torchvision://resnet50', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         add_extra_convs='on_input',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=4,
#         out_channels=256,
#         start_level=0,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#             dict(
#                 bbox_coder=dict(
#                     clip_border=False,
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.5,
#                         0.5,
#                         1.0,
#                         1.0,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 dropout=0.0,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=7,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv'),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=5.0, type='L1Loss'),
#                 loss_cls=dict(
#                     alpha=0.25,
#                     gamma=2.0,
#                     loss_weight=2.0,
#                     type='FocalLoss',
#                     use_sigmoid=True),
#                 loss_iou=dict(loss_weight=2.0, type='GIoULoss'),
#                 num_classes=1,
#                 num_cls_fcs=1,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_reg_fcs=3,
#                 type='DIIHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=2, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         mask_head=[
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#             dict(
#                 class_agnostic=False,
#                 conv_kernel_size=3,
#                 conv_out_channels=256,
#                 dynamic_conv_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=64,
#                     in_channels=256,
#                     input_feat_shape=14,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='DynamicConv',
#                     with_proj=False),
#                 in_channels=256,
#                 loss_mask=dict(
#                     activate=False,
#                     eps=1e-05,
#                     loss_weight=8.0,
#                     type='DiceLoss',
#                     use_sigmoid=True),
#                 norm_cfg=dict(type='BN'),
#                 num_classes=1,
#                 num_convs=4,
#                 roi_feat_size=14,
#                 type='DynamicMaskHead',
#                 upsample_cfg=dict(scale_factor=2, type='deconv')),
#         ],
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=2, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=6,
#         proposal_feature_channel=256,
#         stage_loss_weights=[
#             1,
#             1,
#             1,
#             1,
#             1,
#             1,
#         ],
#         type='SparseRoIHead'),
#     rpn_head=dict(
#         num_proposals=100,
#         proposal_feature_channel=256,
#         type='EmbeddingRPNHead'),
#     test_cfg=dict(rcnn=dict(mask_thr_binary=0.5, max_per_img=100), rpn=None),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#             dict(
#                 assigner=dict(
#                     match_costs=[
#                         dict(type='FocalLossCost', weight=2.0),
#                         dict(box_format='xyxy', type='BBoxL1Cost', weight=5.0),
#                         dict(iou_mode='giou', type='IoUCost', weight=2.0),
#                     ],
#                     type='HungarianAssigner'),
#                 mask_size=28,
#                 pos_weight=1,
#                 sampler=dict(type='PseudoSampler')),
#         ],
#         rpn=None),
#     type='QueryInst')
# num_proposals = 100
# num_stages = 6
# optim_wrapper = dict(
#     optimizer=dict(lr=0.001, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='test/test.json',
#         backend_args=None,
#         data_prefix=dict(img='test/'),
#         data_root='data/swd/',
#         metainfo=dict(
#             classes=('swd', ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     190,
#                     255,
#                     0,
#                 ),
#                 (
#                     153,
#                     153,
#                     153,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='data/swd/test/test.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=100, type='EpochBasedTrainLoop', val_interval=5)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/train.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='data/swd/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=('swd', ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     190,
#                     255,
#                     0,
#                 ),
#                 (
#                     153,
#                     153,
#                     153,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/val.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='data/swd/',
#         metainfo=dict(
#             classes=('swd', ),
#             palette=[
#                 (
#                     220,
#                     20,
#                     60,
#                 ),
#                 (
#                     190,
#                     255,
#                     0,
#                 ),
#                 (
#                     153,
#                     153,
#                     153,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='data/swd/val/val.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = './work_dirs/queryinst_r50_fpn_1x_coco'
#
# 02/20 04:04:35 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/20 04:04:35 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 02/20 04:04:37 - mmengine - INFO - load model from: torchvision://resnet50
# 02/20 04:04:37 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 02/20 04:04:37 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/queryinst/queryinst_r50_fpn_1x_coco/queryinst_r50_fpn_1x_coco_20210907_084916-5a8f1998.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.bbox_head.3.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.3.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.bbox_head.4.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.4.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.bbox_head.5.fc_cls.weight: copying a param with shape torch.Size([80, 256]) from checkpoint, the shape in current model is torch.Size([1, 256]).
# size mismatch for roi_head.bbox_head.5.fc_cls.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.3.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.3.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.4.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.4.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# size mismatch for roi_head.mask_head.5.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([1, 256, 1, 1]).
# size mismatch for roi_head.mask_head.5.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([1]).
# 02/20 04:04:38 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/queryinst/queryinst_r50_fpn_1x_coco/queryinst_r50_fpn_1x_coco_20210907_084916-5a8f1998.pth
# 02/20 04:04:38 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/20 04:04:38 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/20 04:04:38 - mmengine - INFO - Checkpoints will be saved to /home/tianqi/wslProjects/mmdetection_ty/work_dirs/queryinst_r50_fpn_1x_coco.
# 02/20 04:05:02 - mmengine - INFO - Epoch(train)   [1][50/75]  lr: 5.0000e-05  eta: 0:57:43  time: 0.4649  data_time: 0.0128  memory: 3515  loss: 39.5321  s0.loss_cls: 1.7985  s0.pos_acc: 100.0000  s0.loss_bbox: 0.9403  s0.loss_iou: 1.8988  s0.loss_mask: 3.8118  s1.loss_cls: 1.3854  s1.pos_acc: 100.0000  s1.loss_bbox: 0.6391  s1.loss_iou: 1.3042  s1.loss_mask: 2.6205  s2.loss_cls: 1.4800  s2.pos_acc: 100.0000  s2.loss_bbox: 0.5753  s2.loss_iou: 1.0835  s2.loss_mask: 2.8209  s3.loss_cls: 1.8566  s3.pos_acc: 100.0000  s3.loss_bbox: 0.5252  s3.loss_iou: 1.0252  s3.loss_mask: 3.0353  s4.loss_cls: 2.3393  s4.pos_acc: 100.0000  s4.loss_bbox: 0.4991  s4.loss_iou: 0.9680  s4.loss_mask: 2.6117  s5.loss_cls: 2.1844  s5.pos_acc: 100.0000  s5.loss_bbox: 0.4877  s5.loss_iou: 0.9671  s5.loss_mask: 2.6743
# 02/20 04:05:10 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:05:32 - mmengine - INFO - Epoch(train)   [2][50/75]  lr: 1.2500e-04  eta: 0:52:37  time: 0.4337  data_time: 0.0120  memory: 3515  loss: 26.8695  s0.loss_cls: 1.1322  s0.pos_acc: 100.0000  s0.loss_bbox: 1.0881  s0.loss_iou: 2.0478  s0.loss_mask: 3.4879  s1.loss_cls: 0.9075  s1.pos_acc: 100.0000  s1.loss_bbox: 0.5496  s1.loss_iou: 1.1786  s1.loss_mask: 2.0609  s2.loss_cls: 0.7854  s2.pos_acc: 100.0000  s2.loss_bbox: 0.3770  s2.loss_iou: 0.8468  s2.loss_mask: 1.8238  s3.loss_cls: 0.7731  s3.pos_acc: 100.0000  s3.loss_bbox: 0.3470  s3.loss_iou: 0.7570  s3.loss_mask: 1.7233  s4.loss_cls: 0.7575  s4.pos_acc: 100.0000  s4.loss_bbox: 0.3388  s4.loss_iou: 0.7014  s4.loss_mask: 1.6422  s5.loss_cls: 0.9100  s5.pos_acc: 100.0000  s5.loss_bbox: 0.3435  s5.loss_iou: 0.6649  s5.loss_mask: 1.6253
# 02/20 04:05:40 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:06:02 - mmengine - INFO - Epoch(train)   [3][50/75]  lr: 2.0000e-04  eta: 0:50:42  time: 0.4275  data_time: 0.0115  memory: 3515  loss: 30.7528  s0.loss_cls: 1.0398  s0.pos_acc: 100.0000  s0.loss_bbox: 1.5204  s0.loss_iou: 2.3035  s0.loss_mask: 4.8418  s1.loss_cls: 0.8824  s1.pos_acc: 100.0000  s1.loss_bbox: 0.7492  s1.loss_iou: 1.5060  s1.loss_mask: 2.3573  s2.loss_cls: 0.7750  s2.pos_acc: 100.0000  s2.loss_bbox: 0.4817  s2.loss_iou: 1.1264  s2.loss_mask: 1.8651  s3.loss_cls: 0.7517  s3.pos_acc: 100.0000  s3.loss_bbox: 0.4303  s3.loss_iou: 1.0104  s3.loss_mask: 1.7276  s4.loss_cls: 0.7410  s4.pos_acc: 100.0000  s4.loss_bbox: 0.3916  s4.loss_iou: 0.9391  s4.loss_mask: 1.6682  s5.loss_cls: 0.7259  s5.pos_acc: 100.0000  s5.loss_bbox: 0.3835  s5.loss_iou: 0.8854  s5.loss_mask: 1.6496
# 02/20 04:06:10 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:06:32 - mmengine - INFO - Epoch(train)   [4][50/75]  lr: 2.7500e-04  eta: 0:49:51  time: 0.4357  data_time: 0.0115  memory: 3515  loss: 39.9744  s0.loss_cls: 1.0295  s0.pos_acc: 100.0000  s0.loss_bbox: 1.9519  s0.loss_iou: 2.2941  s0.loss_mask: 4.6409  s1.loss_cls: 0.9560  s1.pos_acc: 100.0000  s1.loss_bbox: 1.6711  s1.loss_iou: 2.0830  s1.loss_mask: 3.8049  s2.loss_cls: 0.8794  s2.pos_acc: 100.0000  s2.loss_bbox: 1.2321  s2.loss_iou: 1.6610  s2.loss_mask: 2.8509  s3.loss_cls: 0.7484  s3.pos_acc: 100.0000  s3.loss_bbox: 1.0012  s3.loss_iou: 1.3868  s3.loss_mask: 2.4106  s4.loss_cls: 0.7568  s4.pos_acc: 100.0000  s4.loss_bbox: 0.7824  s4.loss_iou: 1.1893  s4.loss_mask: 2.1014  s5.loss_cls: 0.7522  s5.pos_acc: 100.0000  s5.loss_bbox: 0.7212  s5.loss_iou: 1.0754  s5.loss_mask: 1.9938
# 02/20 04:06:41 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:07:01 - mmengine - INFO - Epoch(train)   [5][50/75]  lr: 3.5000e-04  eta: 0:48:40  time: 0.4179  data_time: 0.0114  memory: 3515  loss: 54.7014  s0.loss_cls: 1.1034  s0.pos_acc: 100.0000  s0.loss_bbox: 2.1084  s0.loss_iou: 2.5310  s0.loss_mask: 5.5092  s1.loss_cls: 1.0704  s1.pos_acc: 100.0000  s1.loss_bbox: 2.1857  s1.loss_iou: 2.5524  s1.loss_mask: 5.5294  s2.loss_cls: 1.0803  s2.pos_acc: 100.0000  s2.loss_bbox: 1.5854  s2.loss_iou: 2.3611  s2.loss_mask: 4.5377  s3.loss_cls: 0.7865  s3.pos_acc: 100.0000  s3.loss_bbox: 1.3704  s3.loss_iou: 2.0401  s3.loss_mask: 3.8348  s4.loss_cls: 0.7741  s4.pos_acc: 100.0000  s4.loss_bbox: 1.2088  s4.loss_iou: 1.8566  s4.loss_mask: 3.6668  s5.loss_cls: 0.7208  s5.pos_acc: 100.0000  s5.loss_bbox: 1.1734  s5.loss_iou: 1.6990  s5.loss_mask: 3.4155
# 02/20 04:07:10 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:07:10 - mmengine - INFO - Saving checkpoint at 5 epochs
# 02/20 04:07:30 - mmengine - INFO - Epoch(val)   [5][50/58]    eta: 0:00:01  time: 0.1745  data_time: 0.0244  memory: 3514
# 02/20 04:07:31 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.16s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.093
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.056
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.155
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.078
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.167
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:07:32 - mmengine - INFO - bbox_mAP_copypaste: 0.045 0.093 0.045 0.019 0.056 -1.000
# 02/20 04:07:32 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.18s).
# Accumulating evaluation results...
# DONE (t=0.07s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.101
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.085
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.243
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:07:32 - mmengine - INFO - segm_mAP_copypaste: 0.059 0.101 0.075 0.025 0.085 -1.000
# 02/20 04:07:32 - mmengine - INFO - Epoch(val) [5][58/58]    coco/bbox_mAP: 0.0450  coco/bbox_mAP_50: 0.0930  coco/bbox_mAP_75: 0.0450  coco/bbox_mAP_s: 0.0190  coco/bbox_mAP_m: 0.0560  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.0590  coco/segm_mAP_50: 0.1010  coco/segm_mAP_75: 0.0750  coco/segm_mAP_s: 0.0250  coco/segm_mAP_m: 0.0850  coco/segm_mAP_l: -1.0000  data_time: 0.0230  time: 0.1716
# 02/20 04:07:34 - mmengine - INFO - The best checkpoint with 0.0450 coco/bbox_mAP at 5 epoch is saved to best_coco_bbox_mAP_epoch_5.pth.
# 02/20 04:08:04 - mmengine - INFO - Epoch(train)   [6][50/75]  lr: 4.2500e-04  eta: 0:47:22  time: 0.3897  data_time: 0.0125  memory: 3515  loss: 52.8526  s0.loss_cls: 1.0597  s0.pos_acc: 100.0000  s0.loss_bbox: 2.1668  s0.loss_iou: 2.4154  s0.loss_mask: 5.6165  s1.loss_cls: 1.0434  s1.pos_acc: 100.0000  s1.loss_bbox: 2.0991  s1.loss_iou: 2.5431  s1.loss_mask: 5.6588  s2.loss_cls: 0.8358  s2.pos_acc: 100.0000  s2.loss_bbox: 1.7544  s2.loss_iou: 2.2116  s2.loss_mask: 4.5424  s3.loss_cls: 0.6713  s3.pos_acc: 100.0000  s3.loss_bbox: 1.3576  s3.loss_iou: 1.9886  s3.loss_mask: 3.7563  s4.loss_cls: 0.6721  s4.pos_acc: 100.0000  s4.loss_bbox: 1.2816  s4.loss_iou: 1.7374  s4.loss_mask: 3.1889  s5.loss_cls: 0.6316  s5.pos_acc: 100.0000  s5.loss_bbox: 1.1626  s5.loss_iou: 1.5729  s5.loss_mask: 2.8847
# 02/20 04:08:15 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# ...
# 02/20 04:55:46 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:56:09 - mmengine - INFO - Epoch(train)  [92][50/75]  lr: 1.0000e-05  eta: 0:04:08  time: 0.4412  data_time: 0.0124  memory: 3515  loss: 9.2171  s0.loss_cls: 0.7471  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4236  s0.loss_iou: 1.3692  s0.loss_mask: 0.6006  s1.loss_cls: 0.7589  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4019  s1.loss_iou: 1.3278  s1.loss_mask: 0.5738  s2.loss_cls: 0.1962  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0981  s2.loss_iou: 0.4366  s2.loss_mask: 0.4336  s3.loss_cls: 0.0990  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0600  s3.loss_iou: 0.2430  s3.loss_mask: 0.3657  s4.loss_cls: 0.0524  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0365  s4.loss_iou: 0.1869  s4.loss_mask: 0.2798  s5.loss_cls: 0.0476  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0305  s5.loss_iou: 0.1748  s5.loss_mask: 0.2735
# 02/20 04:56:17 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:56:39 - mmengine - INFO - Epoch(train)  [93][50/75]  lr: 1.0000e-05  eta: 0:03:39  time: 0.4403  data_time: 0.0124  memory: 3515  loss: 8.3039  s0.loss_cls: 0.7233  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4078  s0.loss_iou: 1.3552  s0.loss_mask: 0.5216  s1.loss_cls: 0.7269  s1.pos_acc: 100.0000  s1.loss_bbox: 0.3879  s1.loss_iou: 1.3148  s1.loss_mask: 0.5207  s2.loss_cls: 0.1510  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0733  s2.loss_iou: 0.3877  s2.loss_mask: 0.2727  s3.loss_cls: 0.0484  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0325  s3.loss_iou: 0.1894  s3.loss_mask: 0.2664  s4.loss_cls: 0.0180  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0263  s4.loss_iou: 0.1556  s4.loss_mask: 0.2662  s5.loss_cls: 0.0147  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0249  s5.loss_iou: 0.1486  s5.loss_mask: 0.2699
# 02/20 04:56:48 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:56:59 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:57:10 - mmengine - INFO - Epoch(train)  [94][50/75]  lr: 1.0000e-05  eta: 0:03:09  time: 0.4409  data_time: 0.0125  memory: 3515  loss: 8.2941  s0.loss_cls: 0.7229  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4225  s0.loss_iou: 1.3709  s0.loss_mask: 0.4044  s1.loss_cls: 0.7322  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4067  s1.loss_iou: 1.3401  s1.loss_mask: 0.4270  s2.loss_cls: 0.1729  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0732  s2.loss_iou: 0.3817  s2.loss_mask: 0.2797  s3.loss_cls: 0.0529  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0374  s3.loss_iou: 0.2067  s3.loss_mask: 0.2673  s4.loss_cls: 0.0350  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0311  s4.loss_iou: 0.1762  s4.loss_mask: 0.2637  s5.loss_cls: 0.0339  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0283  s5.loss_iou: 0.1644  s5.loss_mask: 0.2631
# 02/20 04:57:19 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:57:41 - mmengine - INFO - Epoch(train)  [95][50/75]  lr: 1.0000e-05  eta: 0:02:39  time: 0.4386  data_time: 0.0126  memory: 3515  loss: 8.5998  s0.loss_cls: 0.7019  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4229  s0.loss_iou: 1.3762  s0.loss_mask: 0.5937  s1.loss_cls: 0.7049  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4007  s1.loss_iou: 1.3417  s1.loss_mask: 0.5628  s2.loss_cls: 0.1620  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0780  s2.loss_iou: 0.4115  s2.loss_mask: 0.2724  s3.loss_cls: 0.0405  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0379  s3.loss_iou: 0.2179  s3.loss_mask: 0.2725  s4.loss_cls: 0.0268  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0301  s4.loss_iou: 0.1802  s4.loss_mask: 0.2708  s5.loss_cls: 0.0230  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0278  s5.loss_iou: 0.1695  s5.loss_mask: 0.2741
# 02/20 04:57:49 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:57:49 - mmengine - INFO - Saving checkpoint at 95 epochs
# 02/20 04:58:02 - mmengine - INFO - Epoch(val)  [95][50/58]    eta: 0:00:01  time: 0.1712  data_time: 0.0214  memory: 3515
# 02/20 04:58:03 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.353
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.396
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.211
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:58:04 - mmengine - INFO - bbox_mAP_copypaste: 0.353 0.504 0.465 0.091 0.396 -1.000
# 02/20 04:58:04 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.367
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.493
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.554
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.591
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 04:58:04 - mmengine - INFO - segm_mAP_copypaste: 0.367 0.519 0.493 0.103 0.419 -1.000
# 02/20 04:58:04 - mmengine - INFO - Epoch(val) [95][58/58]    coco/bbox_mAP: 0.3530  coco/bbox_mAP_50: 0.5040  coco/bbox_mAP_75: 0.4650  coco/bbox_mAP_s: 0.0910  coco/bbox_mAP_m: 0.3960  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.3670  coco/segm_mAP_50: 0.5190  coco/segm_mAP_75: 0.4930  coco/segm_mAP_s: 0.1030  coco/segm_mAP_m: 0.4190  coco/segm_mAP_l: -1.0000  data_time: 0.0204  time: 0.1691
# 02/20 04:58:23 - mmengine - INFO - Epoch(train)  [96][50/75]  lr: 1.0000e-05  eta: 0:02:09  time: 0.3847  data_time: 0.0123  memory: 3515  loss: 9.4241  s0.loss_cls: 0.7170  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4942  s0.loss_iou: 1.4951  s0.loss_mask: 0.7048  s1.loss_cls: 0.7173  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4745  s1.loss_iou: 1.4520  s1.loss_mask: 0.7676  s2.loss_cls: 0.1861  s2.pos_acc: 100.0000  s2.loss_bbox: 0.1017  s2.loss_iou: 0.4624  s2.loss_mask: 0.2751  s3.loss_cls: 0.0679  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0377  s3.loss_iou: 0.2052  s3.loss_mask: 0.2727  s4.loss_cls: 0.0371  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0288  s4.loss_iou: 0.1614  s4.loss_mask: 0.2797  s5.loss_cls: 0.0342  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0268  s5.loss_iou: 0.1533  s5.loss_mask: 0.2718
# 02/20 04:58:34 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:58:53 - mmengine - INFO - Epoch(train)  [97][50/75]  lr: 1.0000e-05  eta: 0:01:39  time: 0.3814  data_time: 0.0121  memory: 3515  loss: 9.2395  s0.loss_cls: 0.7183  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4609  s0.loss_iou: 1.4588  s0.loss_mask: 0.7282  s1.loss_cls: 0.7194  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4503  s1.loss_iou: 1.4357  s1.loss_mask: 0.6776  s2.loss_cls: 0.2086  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0862  s2.loss_iou: 0.4387  s2.loss_mask: 0.2734  s3.loss_cls: 0.0669  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0385  s3.loss_iou: 0.2159  s3.loss_mask: 0.2685  s4.loss_cls: 0.0324  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0297  s4.loss_iou: 0.1711  s4.loss_mask: 0.2709  s5.loss_cls: 0.0264  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0279  s5.loss_iou: 0.1636  s5.loss_mask: 0.2715
# 02/20 04:59:04 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:59:23 - mmengine - INFO - Epoch(train)  [98][50/75]  lr: 1.0000e-05  eta: 0:01:09  time: 0.3733  data_time: 0.0122  memory: 3515  loss: 9.1923  s0.loss_cls: 0.7221  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4689  s0.loss_iou: 1.4732  s0.loss_mask: 0.7252  s1.loss_cls: 0.7190  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4613  s1.loss_iou: 1.4453  s1.loss_mask: 0.6251  s2.loss_cls: 0.2132  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0853  s2.loss_iou: 0.4354  s2.loss_mask: 0.2553  s3.loss_cls: 0.0503  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0392  s3.loss_iou: 0.2194  s3.loss_mask: 0.2641  s4.loss_cls: 0.0306  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0313  s4.loss_iou: 0.1784  s4.loss_mask: 0.2683  s5.loss_cls: 0.0274  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0275  s5.loss_iou: 0.1584  s5.loss_mask: 0.2684
# 02/20 04:59:33 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 04:59:52 - mmengine - INFO - Epoch(train)  [99][50/75]  lr: 1.0000e-05  eta: 0:00:39  time: 0.3743  data_time: 0.0122  memory: 3515  loss: 8.3251  s0.loss_cls: 0.6860  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4072  s0.loss_iou: 1.3125  s0.loss_mask: 0.5815  s1.loss_cls: 0.6812  s1.pos_acc: 100.0000  s1.loss_bbox: 0.3915  s1.loss_iou: 1.2841  s1.loss_mask: 0.5337  s2.loss_cls: 0.1565  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0747  s2.loss_iou: 0.3986  s2.loss_mask: 0.2818  s3.loss_cls: 0.0605  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0366  s3.loss_iou: 0.2109  s3.loss_mask: 0.2651  s4.loss_cls: 0.0261  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0295  s4.loss_iou: 0.1731  s4.loss_mask: 0.2665  s5.loss_cls: 0.0155  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0267  s5.loss_iou: 0.1574  s5.loss_mask: 0.2679
# 02/20 05:00:03 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 05:00:22 - mmengine - INFO - Epoch(train) [100][50/75]  lr: 1.0000e-05  eta: 0:00:09  time: 0.3788  data_time: 0.0122  memory: 3515  loss: 8.3312  s0.loss_cls: 0.7053  s0.pos_acc: 100.0000  s0.loss_bbox: 0.4279  s0.loss_iou: 1.3874  s0.loss_mask: 0.4787  s1.loss_cls: 0.7014  s1.pos_acc: 100.0000  s1.loss_bbox: 0.4174  s1.loss_iou: 1.3637  s1.loss_mask: 0.4767  s2.loss_cls: 0.1780  s2.pos_acc: 100.0000  s2.loss_bbox: 0.0784  s2.loss_iou: 0.4156  s2.loss_mask: 0.2567  s3.loss_cls: 0.0375  s3.pos_acc: 100.0000  s3.loss_bbox: 0.0348  s3.loss_iou: 0.2016  s3.loss_mask: 0.2572  s4.loss_cls: 0.0164  s4.pos_acc: 100.0000  s4.loss_bbox: 0.0281  s4.loss_iou: 0.1613  s4.loss_mask: 0.2573  s5.loss_cls: 0.0132  s5.pos_acc: 100.0000  s5.loss_bbox: 0.0258  s5.loss_iou: 0.1502  s5.loss_mask: 0.2606
# 02/20 05:00:32 - mmengine - INFO - Exp name: queryinst_r50_fpn_1x_coco_20250220_040431
# 02/20 05:00:32 - mmengine - INFO - Saving checkpoint at 100 epochs
# /home/tianqi/miniconda3/envs/mmcv/lib/python3.10/site-packages/mmengine/visualization/visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# /home/tianqi/miniconda3/envs/mmcv/lib/python3.10/site-packages/mmengine/visualization/visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
# 02/20 05:00:44 - mmengine - INFO - Epoch(val) [100][50/58]    eta: 0:00:01  time: 0.1304  data_time: -0.0197  memory: 3515
# 02/20 05:00:46 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.454
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.539
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 05:00:46 - mmengine - INFO - bbox_mAP_copypaste: 0.371 0.571 0.454 0.149 0.415 -1.000
# 02/20 05:00:46 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.15s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.569
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.501
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = -1.000
# 02/20 05:00:46 - mmengine - INFO - segm_mAP_copypaste: 0.391 0.569 0.501 0.142 0.447 -1.000
# 02/20 05:00:46 - mmengine - INFO - Epoch(val) [100][58/58]    coco/bbox_mAP: 0.3710  coco/bbox_mAP_50: 0.5710  coco/bbox_mAP_75: 0.4540  coco/bbox_mAP_s: 0.1490  coco/bbox_mAP_m: 0.4150  coco/bbox_mAP_l: -1.0000  coco/segm_mAP: 0.3910  coco/segm_mAP_50: 0.5690  coco/segm_mAP_75: 0.5010  coco/segm_mAP_s: 0.1420  coco/segm_mAP_m: 0.4470  coco/segm_mAP_l: -1.0000  data_time: -0.0090  time: 0.1383
# 02/20 05:00:46 - mmengine - INFO - The previous best checkpoint /home/tianqi/wslProjects/mmdetection_ty/work_dirs/queryinst_r50_fpn_1x_coco/best_coco_bbox_mAP_epoch_90.pth is removed
# 02/20 05:00:50 - mmengine - INFO - The best checkpoint with 0.3710 coco/bbox_mAP at 100 epoch is saved to best_coco_bbox_mAP_epoch_100.pth.
