# %%
# !python tools/train.py configs/swd/mask-rcnn_r50-caffe_fpn_ms-poly-1x_coco.py
# Out:
# /home/tianqi/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 01/21 20:29:22 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1330091595
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python tools/train.py configs/swd/mask-rcnn_r50_fpn_1x_coco.py
# Out:
# /home/tianqi/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 01/21 21:13:23 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 258527407
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python tools/train.py configs/swd/mask-rcnn_r101_fpn_1x_coco.py
# Out:
# /home/tianqi/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 01/21 21:47:04 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1303257723
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python tools/train.py configs/swd/mask-rcnn_r101_fpn_ms-poly-3x_coco.py

# %%
# !python tools/train.py configs/swd/mask-rcnn_x101-32x4d_fpn_1x_coco.py
# Out:
# /home/tianqi/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 01/21 22:25:45 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1647089393
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python tools/train.py configs/swd/mask-rcnn_x101-64x4d_fpn_1x_coco.py
# Out:
# /home/tianqi/miniconda3/envs/openmmlab/lib/python3.8/site-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \
# 01/24 02:05:48 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.8.20 (default, Oct  3 2024, 15:24:27) [GCC 11.2.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 656648567
#     GPU 0: NVIDIA GeForce RTX 3070 Laptop GPU
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.1, V12.1.105
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.2) 9.4.0
#     PyTorch: 2.4.1+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
# ...

# %%
# !python tools/train.py configs/swd/mask2former_r50_8xb2-lsj-50e_coco.py

# %%
# from mmdet.apis import DetInferencer
#
# # 初始化模型
# inferencer = DetInferencer('rtmdet_tiny_8xb32-300e_coco')
# # inferencer = DetInferencer(model='rtmdet_tiny_8xb32-300e_coco', weights='checkpoints/swd_yolo11_best.pt')
# inferencer = DetInferencer(model='rtmdet_tiny_8xb32-300e_coco', device='cuda:0')
#
# # 推理示例图片
# inferencer('demo/demo.jpg', show=True, out_dir='results/',no_save_pred=False)

# %%
# from PIL import Image
# result_img = Image.open('results/vis/demo.jpg')  # 根据保存的文件名调整路径
# result_img.show()

# %%
# !tensorboard --logdir "work_dirs" --port 6006
